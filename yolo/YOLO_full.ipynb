# %% [markdown]
# # YOLO
# The goal of this notebook is to do transfer learning of Fishial´s already implemented YOLO model. We do this by using Ultralytics

# %%
from ultralytics import YOLO
import os
import requests
import logging
from zipfile import ZipFile
import pandas as pd
import torch
import cv2
import matplotlib.pyplot as plt
import copy
from IPython.display import Image, display

from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models

# %%
DATA_DIR = "../data_csv/"
timor_leste_data_path = os.path.join(DATA_DIR, "timor-leste.csv") # Annotation info for ground truth
images_path = "../data_images/"

# %%
import re

def extract_and_format_species(big_string):
    # Find all genus_species patterns (ignore numbers)
    matches = re.findall(r"\b([a-z]+_[a-z]+)\b", big_string)

    formatted = []
    for species in matches:
        genus, epithet = species.split("_")
        formatted.append(f"{genus.capitalize()} {epithet}")

    return formatted

big_string = """
acanthocybium_solandri	
29
alectis_ciliaris	
15
amblygaster_sirm	
1
aphareus_rutilans	
3
arius_arius	
1
aurigequula_fasciata	
70
carangoides_praeustus	
1
caranx_ignobilis	
41
caranx_lugubris	
1
caranx_melampygus	
9
caranx_sexfasciatus	
1
caranx_tille	
1
chirocentrus_dorab	
81
chirocentrus_nudus	
2
decapterus_macarellus	
52
decapterus_macrosoma	
4
elagatis_bipinnulata	
8
elagatos_bipinnulata	
1
epinephelus_maculatus	
19
epinephelus_radiatus	
6
etelis_carbunculus	
16
gazza_minuta	
59
gymnocranius_grandoculis	
38
katsuwonus_pelamis	
10
lethrinus_erythracanthus	
2
lethrinus_mahsena	
13
lethrinus_obsoletus	
1
lethrinus_ornatus	
1
lethrinus_reticulatus	
1
lujanus_gibbus	
51
lutjanus_bohar	
3
lutjanus_fulviflamma	
27
lutjanus_fulvus	
47
lutjanus_gibbus	
3
lutjanus_johnii	
68
lutjanus_kasmira	
10
lutjanus_rivulatus	
1
lutjanus_rufolineatus	
2
lutjanus_russellii	
7
monotaxis_grandoculis	
7
mulloidichtys_vanicolensis	
75
neoniphon_sammara	
15
parupeneus_heptacanthus	
24
parupeneus_indicus	
13
platax_boersii	
1
plectorhinchus_vittatus	
2
pomacanthus_annularis	
1
pomadasys_argenteus	
33
pomadasys_kaakan	
46
priacanthus_sagittarius	
1
pristigenys_niphonia	
15
psettodes_erumei	
3
pseudobalistes_flavimarginatus	
8
rastrelliger_kanagurta	
129
sardinella_albella	
16
scarus_quoyi	
2
scolopsis_vosmeri	
4
scomberoides_lysan	
1
scomberoides_tol	
106
scomberomorus_commerson	
28
seriola_dumerili	
1
siganus_spinus	
1
upeneus_vittatus	
77
variola_albimarginata	
7
"""

relevant_species = extract_and_format_species(big_string)

print(relevant_species)
# Out:
# ['Acanthocybium solandri', 'Alectis ciliaris', 'Amblygaster sirm', 'Aphareus rutilans', 'Arius arius', 'Aurigequula fasciata', 'Carangoides praeustus', 'Caranx ignobilis', 'Caranx lugubris', 'Caranx melampygus', 'Caranx sexfasciatus', 'Caranx tille', 'Chirocentrus dorab', 'Chirocentrus nudus', 'Decapterus macarellus', 'Decapterus macrosoma', 'Elagatis bipinnulata', 'Elagatos bipinnulata', 'Epinephelus maculatus', 'Epinephelus radiatus', 'Etelis carbunculus', 'Gazza minuta', 'Gymnocranius grandoculis', 'Katsuwonus pelamis', 'Lethrinus erythracanthus', 'Lethrinus mahsena', 'Lethrinus obsoletus', 'Lethrinus ornatus', 'Lethrinus reticulatus', 'Lujanus gibbus', 'Lutjanus bohar', 'Lutjanus fulviflamma', 'Lutjanus fulvus', 'Lutjanus gibbus', 'Lutjanus johnii', 'Lutjanus kasmira', 'Lutjanus rivulatus', 'Lutjanus rufolineatus', 'Lutjanus russellii', 'Monotaxis grandoculis', 'Mulloidichtys vanicolensis', 'Neoniphon sammara', 'Parupeneus heptacanthus', 'Parupeneus indicus', 'Platax boersii', 'Plectorhinchus vittatus', 'Pomacanthus annularis', 'Pomadasys argenteus', 'Pomadasys kaakan', 'Priacanthus sagittarius', 'Pristigenys niphonia', 'Psettodes erumei', 'Pseudobalistes flavimarginatus', 'Rastrelliger kanagurta', 'Sardinella albella', 'Scarus quoyi', 'Scolopsis vosmeri', 'Scomberoides lysan', 'Scomberoides tol', 'Scomberomorus commerson', 'Seriola dumerili', 'Siganus spinus', 'Upeneus vittatus', 'Variola albimarginata']

# %%
# Read annotation info (Timor-leste)
df_tl_ann = pd.read_csv(timor_leste_data_path, encoding="utf-8-sig", header=0, skiprows=1)
df_tl_ann = df_tl_ann[["image_file", "catch_name_en", "Species_name", "Family"]]

# Filter by species in relevant_species
df_filtered = df_tl_ann[df_tl_ann["Species_name"].isin(relevant_species)]

# Keep only images that actually exist
existing_files = set(os.listdir(images_path))

df_filtered = df_filtered[df_filtered["image_file"].isin(existing_files)]

# Convert to list of filenames
filtered_images= df_filtered["image_file"].tolist()

print("Total annotated images:", len(df_tl_ann))
print("Relevant images", len(df_filtered))
print("Unique final JPGs:", len(set(filtered_images)))
# Out:
# Total annotated images: 603
# Relevant images 295
# Unique final JPGs: 247

# %%
def on_train_epoch_end(trainer):
    print(f"Finished epoch {trainer.epoch}/{trainer.epochs}")

model = YOLO("yolo11n.pt")

model.add_callback("on_train_epoch_end", on_train_epoch_end)

# Train the model
train_results = model.train(
    data="full_dataset/data.yaml",
    epochs=300,
    imgsz=640,
    device="cuda",
    patience=30
)

# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# New https://pypi.org/project/ultralytics/8.3.236 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.12.10 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=full_dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=64
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     18496  ultralytics.nn.modules.conv.Conv             [64, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    443152  ultralytics.nn.modules.head.Detect           [64, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,617,536 parameters, 2,617,520 gradients, 7.5 GFLOPs
#
# Transferred 443/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 93.541.6 MB/s, size: 18.0 KB)
# train: Scanning C:\Users\kienn\Downloads\Prosjektoppgave\yolo\full_dataset\train\labels.cache... 2479 images, 933 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2479/2479 2.5Mit/s 0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 3173, len(boxes) = 3377. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.00.0 ms, read: 74.410.5 MB/s, size: 14.0 KB)
# val: Scanning C:\Users\kienn\Downloads\Prosjektoppgave\yolo\full_dataset\valid\labels.cache... 208 images, 124 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 208/208  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 176, len(boxes) = 195. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      3.39G      1.596      5.235      1.802         43        640: 100% ━━━━━━━━━━━━ 155/155 6.8it/s 22.6s0.1ss
# Finished epoch 0/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4s/it 9.7s1.6ss
#                    all        208        195    0.00438       0.03    0.00608    0.00364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      5.69G      1.379      4.894      1.606         29        640: 100% ━━━━━━━━━━━━ 155/155 12.4it/s 12.5s0.2s
# Finished epoch 1/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.1it/s 0.5s.1s
#                    all        208        195      0.691       0.06     0.0681     0.0431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      5.69G      1.471      4.567      1.683         53        640: 100% ━━━━━━━━━━━━ 155/155 12.9it/s 12.1s0.2s
# Finished epoch 2/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 12.6it/s 0.6s.1s
#                    all        208        195      0.959     0.0238     0.0509     0.0301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300       5.7G      1.586      4.301      1.756         51        640: 100% ━━━━━━━━━━━━ 155/155 12.0it/s 12.9s0.1s
# Finished epoch 3/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 11.9it/s 0.6s.1s
#                    all        208        195      0.571     0.0829     0.0695     0.0323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      5.71G      1.545      4.122      1.722         37        640: 100% ━━━━━━━━━━━━ 155/155 12.7it/s 12.2s0.1s
# Finished epoch 4/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.2it/s 0.5s.1s
#                    all        208        195       0.35      0.191      0.131     0.0722
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      5.71G      1.512      3.803      1.667         76        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 5/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.9it/s 0.5s.1s
#                    all        208        195      0.494      0.188      0.162      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      5.71G      1.444       3.66      1.611         54        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.6s0.1s
# Finished epoch 6/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.4it/s 0.5s.1s
#                    all        208        195      0.294      0.216      0.171      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      5.72G      1.415      3.524      1.588         56        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.5s0.1s
# Finished epoch 7/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.7it/s 0.5s.1s
#                    all        208        195      0.314      0.302      0.227      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      5.72G      1.398      3.412      1.568         61        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 8/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.8it/s 0.5s.1s
#                    all        208        195      0.389      0.217      0.198      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      5.73G      1.378      3.275      1.537         28        640: 100% ━━━━━━━━━━━━ 155/155 13.3it/s 11.6s0.1s
# Finished epoch 9/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.3it/s 0.5s.1s
#                    all        208        195      0.364      0.269      0.258      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      5.73G      1.346      3.111      1.512         44        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 10/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.0it/s 0.5s.1s
#                    all        208        195      0.369      0.367      0.272       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      5.73G      1.329      2.996      1.495         35        640: 100% ━━━━━━━━━━━━ 155/155 11.9it/s 13.0s0.1s
# Finished epoch 11/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.2it/s 0.5s.1s
#                    all        208        195      0.334      0.329      0.257      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      5.73G      1.299      2.888      1.484         42        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.2s
# Finished epoch 12/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.9it/s 0.5s.1s
#                    all        208        195      0.328       0.33      0.343      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      5.73G      1.295      2.798      1.475         89        640: 100% ━━━━━━━━━━━━ 155/155 12.9it/s 12.0s0.2s
# Finished epoch 13/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.6it/s 0.5s.1s
#                    all        208        195      0.467       0.32      0.345      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      5.73G      1.282      2.675      1.451         54        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.2s
# Finished epoch 14/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.8it/s 0.5s.1s
#                    all        208        195      0.312      0.363      0.323      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      5.73G      1.262      2.619      1.447         44        640: 100% ━━━━━━━━━━━━ 155/155 12.9it/s 12.1s0.1s
# Finished epoch 15/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.2it/s 0.5s.1s
#                    all        208        195      0.403      0.343      0.322      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      5.73G       1.26      2.545      1.438         29        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.1s
# Finished epoch 16/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.7it/s 0.5s.1s
#                    all        208        195      0.391      0.407      0.365      0.253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/300      5.73G      1.227       2.38      1.414         50        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.1s
# Finished epoch 17/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.6it/s 0.5s.1s
#                    all        208        195      0.341      0.421      0.355      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/300      5.73G      1.217      2.377      1.409         41        640: 100% ━━━━━━━━━━━━ 155/155 13.0it/s 12.0s0.2s
# Finished epoch 18/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.7it/s 0.5s.1s
#                    all        208        195      0.354      0.393      0.363      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/300      5.73G      1.184      2.218      1.373         33        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.1s
# Finished epoch 19/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.2it/s 0.5s.1s
#                    all        208        195      0.386      0.343      0.369      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/300      5.73G      1.169      2.168       1.37         40        640: 100% ━━━━━━━━━━━━ 155/155 12.7it/s 12.2s0.2s
# Finished epoch 20/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.2it/s 0.5s.1s
#                    all        208        195      0.619      0.241      0.341      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/300      5.73G      1.167      2.089      1.366         48        640: 100% ━━━━━━━━━━━━ 155/155 12.9it/s 12.0s0.1s
# Finished epoch 21/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.0it/s 0.5s.1s
#                    all        208        195      0.452      0.324      0.347      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/300      5.73G      1.164      2.107      1.369         24        640: 100% ━━━━━━━━━━━━ 155/155 12.7it/s 12.2s0.2s
# Finished epoch 22/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 12.6it/s 0.6s.1s
#                    all        208        195      0.339      0.415      0.342       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/300      5.73G      1.149      1.986      1.362         46        640: 100% ━━━━━━━━━━━━ 155/155 12.5it/s 12.4s0.1s
# Finished epoch 23/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 12.0it/s 0.6s.1s
#                    all        208        195      0.312      0.477      0.378      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/300      5.73G      1.141      1.946      1.351         67        640: 100% ━━━━━━━━━━━━ 155/155 13.2it/s 11.8s0.1s
# Finished epoch 24/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.7it/s 0.4s.1s
#                    all        208        195      0.337      0.412       0.42       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/300      5.73G      1.119      1.926      1.336         38        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 25/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.1it/s 0.5s.1s
#                    all        208        195      0.566      0.275      0.368      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/300      5.73G      1.123      1.894      1.337         32        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.4s0.1s
# Finished epoch 26/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.9it/s 0.5s.1s
#                    all        208        195      0.428      0.423       0.41      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/300      5.73G      1.096       1.84      1.319         39        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 27/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.0it/s 0.5s.1s
#                    all        208        195      0.401      0.354      0.355       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/300      5.73G        1.1      1.764      1.311         61        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 28/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.5it/s 0.5s.1s
#                    all        208        195      0.414      0.363      0.391      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/300      5.73G      1.074      1.702      1.304         65        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 29/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.2it/s 0.4s.1s
#                    all        208        195      0.361      0.412      0.421      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/300      5.73G      1.065       1.71      1.292         28        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 30/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.4it/s 0.5s.1s
#                    all        208        195      0.493      0.375      0.403      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/300      5.73G      1.059      1.633      1.293         44        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 31/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.2it/s 0.5s.1s
#                    all        208        195      0.291      0.482      0.387      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/300      5.73G       1.06      1.604      1.284         46        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 32/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.5it/s 0.5s.1s
#                    all        208        195      0.379      0.407      0.381      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/300      5.73G      1.047      1.596      1.287         28        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 33/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.1it/s 0.5s.1s
#                    all        208        195       0.43      0.394      0.461      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/300      5.73G      1.025      1.535      1.269         64        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 34/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.4it/s 0.5s.1s
#                    all        208        195      0.399      0.432      0.422      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/300      5.73G       1.02      1.513      1.261         42        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 35/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.3it/s 0.5s.1s
#                    all        208        195      0.627      0.348      0.417      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/300      5.73G      1.022      1.484      1.265         57        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 36/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195      0.311      0.505      0.412        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/300      5.73G      1.025      1.444       1.26         86        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 37/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.9it/s 0.5s.1s
#                    all        208        195      0.512      0.413      0.432      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/300      5.73G     0.9963      1.411      1.246         21        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 38/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.0it/s 0.5s.1s
#                    all        208        195      0.448      0.371      0.404      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/300      5.73G     0.9926      1.417      1.246         39        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 39/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.6it/s 0.5s.1s
#                    all        208        195      0.561      0.396       0.45       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/300      5.73G     0.9948      1.348      1.245         64        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.4s0.1s
# Finished epoch 40/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.3it/s 0.5s.1s
#                    all        208        195      0.437      0.394      0.422      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/300      5.73G     0.9758      1.353      1.235         47        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 41/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.2it/s 0.5s.1s
#                    all        208        195      0.553      0.372      0.424      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/300      5.73G     0.9977      1.323      1.245         36        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.2s
# Finished epoch 42/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.547      0.357      0.433      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/300      5.73G     0.9831      1.325       1.24         58        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 43/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.9it/s 0.5s.1s
#                    all        208        195      0.481      0.452      0.432      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/300      5.73G     0.9658      1.268      1.221         62        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 44/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.4it/s 0.5s.1s
#                    all        208        195      0.453        0.4      0.413      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/300      5.73G     0.9617      1.266      1.221         40        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 45/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.3it/s 0.5s.1s
#                    all        208        195      0.601        0.4      0.455       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/300      5.73G     0.9586       1.24      1.214         48        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.6s0.1s
# Finished epoch 46/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.2it/s 0.5s.1s
#                    all        208        195      0.587      0.381      0.436      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/300      5.73G     0.9407      1.218      1.215         33        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 47/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195      0.524      0.376      0.449      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/300      5.73G     0.9577      1.192      1.225         39        640: 100% ━━━━━━━━━━━━ 155/155 13.2it/s 11.7s0.1s
# Finished epoch 48/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195       0.45      0.416      0.419      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/300      5.73G     0.9499      1.213      1.215         49        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 49/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.6it/s 0.5s.1s
#                    all        208        195      0.483      0.338      0.401      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/300      5.73G     0.9364      1.181      1.208         51        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.2s
# Finished epoch 50/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.8it/s 0.4s.1s
#                    all        208        195      0.537      0.404      0.436      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/300      5.73G     0.9089      1.121      1.198         29        640: 100% ━━━━━━━━━━━━ 155/155 13.3it/s 11.7s0.1s
# Finished epoch 51/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.464      0.411      0.436      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/300      5.73G     0.9349      1.139      1.201         72        640: 100% ━━━━━━━━━━━━ 155/155 12.9it/s 12.0s0.2s
# Finished epoch 52/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 12.6it/s 0.6s.1s
#                    all        208        195      0.397      0.457      0.481      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/300      5.73G      0.928      1.143      1.208         37        640: 100% ━━━━━━━━━━━━ 155/155 12.3it/s 12.6s0.1s
# Finished epoch 53/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 12.5it/s 0.6s.1s
#                    all        208        195      0.476      0.391      0.425      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/300      5.73G     0.9005      1.098       1.19         43        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.4s0.1s
# Finished epoch 54/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.8it/s 0.4s.1s
#                    all        208        195      0.409      0.494      0.439       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/300      5.73G     0.9052      1.105       1.19         36        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 55/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195      0.487      0.478      0.466      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/300      5.73G     0.8962      1.055      1.179         74        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 56/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.4it/s 0.5s.1s
#                    all        208        195      0.448      0.405      0.419      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/300      5.73G     0.8931      1.091      1.184         25        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 57/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195      0.454      0.463      0.462      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/300      5.73G     0.8868      1.055      1.186         42        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 58/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.3it/s 0.4s.1s
#                    all        208        195      0.484      0.416      0.467      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/300      5.73G     0.8795      1.032      1.181         45        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 59/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.391      0.463      0.448      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/300      5.73G     0.8826      1.034      1.174         61        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 60/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.3it/s 0.4s.1s
#                    all        208        195      0.572       0.42      0.414      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/300      5.73G     0.8877      1.041      1.176         37        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 61/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.7it/s 0.4s.1s
#                    all        208        195      0.608      0.373      0.436      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/300      5.73G      0.886      1.007      1.169         65        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 62/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.472      0.343      0.409      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/300      5.73G     0.8617     0.9993      1.164         28        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 63/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.2it/s 0.4s.1s
#                    all        208        195      0.539      0.442      0.441      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/300      5.73G     0.8979     0.9945      1.174         36        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 64/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.3it/s 0.4s.1s
#                    all        208        195      0.492      0.449      0.441      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/300      5.73G     0.8575     0.9765      1.154         43        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 65/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195       0.44      0.423      0.424      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/300      5.73G     0.8691     0.9647      1.161         58        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 66/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.8it/s 0.4s0.1s
#                    all        208        195      0.475      0.405      0.443      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/300      5.73G      0.849     0.9507      1.154         90        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 67/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.2it/s 0.4s.1s
#                    all        208        195      0.362      0.487      0.427      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/300      5.73G     0.8435     0.9393      1.148         41        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 68/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.6it/s 0.4s.1s
#                    all        208        195      0.546      0.442      0.469      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/300      5.73G     0.8369     0.9204      1.144         41        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.6s0.1s
# Finished epoch 69/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.3it/s 0.4s.1s
#                    all        208        195      0.528      0.419      0.481      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/300      5.73G     0.8535     0.9369      1.147         35        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.2s
# Finished epoch 70/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.9it/s 0.4s0.1s
#                    all        208        195      0.431      0.413      0.436       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/300      5.73G     0.8517      0.939      1.154         33        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 71/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.7it/s 0.4s.1s
#                    all        208        195      0.599      0.391      0.452      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/300      5.73G     0.8526     0.9276      1.152         36        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 72/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.413      0.455      0.424      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/300      5.73G     0.8456     0.9288      1.148         46        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.6s0.1s
# Finished epoch 73/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195      0.409      0.452       0.41       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/300      5.73G     0.8436     0.9128      1.153         57        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 74/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.5it/s 0.4s.1s
#                    all        208        195      0.486      0.423      0.455      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/300      5.73G     0.8374     0.8961      1.139         68        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.4s0.1s
# Finished epoch 75/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.8it/s 0.4s.1s
#                    all        208        195       0.44      0.463      0.466      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/300      5.73G     0.8078     0.8673      1.122         70        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 76/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195      0.451      0.443      0.478      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/300      5.73G      0.803     0.8636      1.129         20        640: 100% ━━━━━━━━━━━━ 155/155 13.3it/s 11.6s0.1s
# Finished epoch 77/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.1it/s 0.5s.1s
#                    all        208        195      0.456      0.488      0.469      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/300      5.73G     0.8198      0.862      1.128         25        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.5s0.1s
# Finished epoch 78/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195      0.536      0.444       0.47      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/300      5.73G     0.8335     0.8915      1.132         28        640: 100% ━━━━━━━━━━━━ 155/155 13.2it/s 11.7s0.1s
# Finished epoch 79/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195      0.431      0.507      0.453      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/300      5.73G     0.8019     0.8516      1.132         86        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.5s0.1s
# Finished epoch 80/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.7it/s 0.4s.1s
#                    all        208        195      0.391      0.507      0.461      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/300      5.73G     0.8035     0.8454      1.127         54        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.1s
# Finished epoch 81/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 14.6it/s 0.5s.1s
#                    all        208        195      0.604      0.466      0.476      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/300      5.73G     0.8116     0.8399      1.126         37        640: 100% ━━━━━━━━━━━━ 155/155 13.1it/s 11.8s0.2s
# Finished epoch 82/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.8it/s 0.4s.1s
#                    all        208        195      0.373       0.47      0.429      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/300      5.73G     0.7968     0.8307       1.12         28        640: 100% ━━━━━━━━━━━━ 155/155 12.8it/s 12.1s0.1s
# Finished epoch 83/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.4it/s 0.4s.1s
#                    all        208        195      0.433       0.52      0.444      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/300      5.73G     0.7921     0.8176      1.118         69        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 84/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.5it/s 0.4s.1s
#                    all        208        195      0.437       0.47      0.467      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/300      5.73G     0.8031     0.8247      1.126         27        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 85/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.1it/s 0.4s.1s
#                    all        208        195      0.372      0.471      0.416      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/300      5.73G     0.7968     0.8135      1.114         49        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 86/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.9it/s 0.4s0.1s
#                    all        208        195      0.619      0.401      0.458      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/300      5.73G     0.7839      0.815      1.114         39        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 87/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.2it/s 0.4s.1s
#                    all        208        195      0.429        0.5      0.471       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/300      5.73G     0.7883     0.8039      1.113         52        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 88/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.6it/s 0.4s.1s
#                    all        208        195      0.408       0.47      0.466      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/300      5.73G     0.7758     0.7904      1.106         31        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 89/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.3it/s 0.4s.1s
#                    all        208        195      0.447      0.471      0.471       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/300      5.73G     0.7667     0.7872      1.101         49        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.2s
# Finished epoch 90/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.8it/s 0.4s.1ss
#                    all        208        195        0.6      0.422      0.483      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/300      5.73G     0.7742     0.8026       1.11         55        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 91/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.8it/s 0.4s.1ss
#                    all        208        195      0.516      0.425       0.45      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/300      5.73G     0.7655     0.7874        1.1         47        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 92/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.0it/s 0.4s.1s
#                    all        208        195       0.53      0.464      0.478      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/300      5.73G     0.7621     0.7834      1.111         30        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 93/300
# ...
# Finished epoch 163/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.0it/s 0.4s.1s
#                    all        208        195      0.477      0.528      0.487      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     165/300      5.73G     0.6289      0.558      1.022         25        640: 100% ━━━━━━━━━━━━ 155/155 13.7it/s 11.3s0.1s
# Finished epoch 164/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.7it/s 0.4s.1s
#                    all        208        195      0.492      0.534      0.491      0.393
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     166/300      5.73G     0.6236     0.5406      1.029         57        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 165/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.3it/s 0.4s.1s
#                    all        208        195      0.489      0.517      0.484      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     167/300      5.73G     0.6238     0.5604      1.027         49        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 166/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.5it/s 0.4s.1s
#                    all        208        195       0.55      0.465      0.472      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     168/300      5.73G     0.6278     0.5511      1.023         68        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 167/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.4it/s 0.4s.1s
#                    all        208        195      0.593      0.413      0.459      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     169/300      5.73G     0.6222     0.5442      1.033         47        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 168/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.0it/s 0.4s.1s
#                    all        208        195      0.518      0.465      0.466      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     170/300      5.73G     0.6144     0.5429       1.02         38        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 169/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.4it/s 0.4s.1s
#                    all        208        195      0.495      0.415      0.459      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     171/300      5.73G     0.6147     0.5353      1.027         46        640: 100% ━━━━━━━━━━━━ 155/155 13.2it/s 11.8s0.2s
# Finished epoch 170/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.7it/s 0.4s.1s
#                    all        208        195      0.403      0.509      0.457      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     172/300      5.73G     0.6083     0.5225      1.023         82        640: 100% ━━━━━━━━━━━━ 155/155 12.3it/s 12.6s0.2s
# Finished epoch 171/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.7it/s 0.4s.1s
#                    all        208        195      0.505      0.507      0.476      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     173/300      5.73G     0.6207     0.5463      1.026         27        640: 100% ━━━━━━━━━━━━ 155/155 13.1it/s 11.8s0.2s
# Finished epoch 172/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 15.9it/s 0.4s.1s
#                    all        208        195      0.591      0.458      0.495      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/300      5.73G     0.6145     0.5394       1.02         58        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 173/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.4it/s 0.4s.1s
#                    all        208        195        0.6      0.441      0.486      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/300      5.73G     0.5989     0.5253      1.013         24        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.2s
# Finished epoch 174/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.1it/s 0.4s.1s
#                    all        208        195      0.533      0.453       0.47      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/300      5.73G     0.6023     0.5279      1.017         48        640: 100% ━━━━━━━━━━━━ 155/155 13.4it/s 11.5s0.1s
# Finished epoch 175/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 16.8it/s 0.4s.1ss
#                    all        208        195      0.527      0.489      0.486      0.387
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/300      5.73G     0.6161     0.5271      1.021         46        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 176/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.4it/s 0.4s.1s
#                    all        208        195      0.561      0.443      0.479      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/300      5.73G     0.6009     0.5231      1.016         54        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.1s
# Finished epoch 177/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.3it/s 0.4s.1s
#                    all        208        195      0.492        0.5        0.5      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/300      5.73G     0.5986     0.5159      1.014         37        640: 100% ━━━━━━━━━━━━ 155/155 13.5it/s 11.5s0.2s
# Finished epoch 178/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.5it/s 0.4s.1s
#                    all        208        195      0.583      0.437      0.496      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/300      5.73G     0.5981     0.5285      1.015         51        640: 100% ━━━━━━━━━━━━ 155/155 13.6it/s 11.4s0.1s
# Finished epoch 179/300
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 17.3it/s 0.4s.1s
#                    all        208        195      0.486      0.533      0.494      0.398
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 150, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 180 epochs completed in 0.615 hours.
# Optimizer stripped from C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6\weights\last.pt, 5.5MB
# Optimizer stripped from C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6\weights\best.pt, 5.5MB
#
# Validating C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6\weights\best.pt...
# Ultralytics 8.3.235  Python-3.12.10 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO11n summary (fused): 100 layers, 2,609,800 parameters, 0 gradients, 7.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 13.5it/s 0.5s.1s
#                    all        208        195      0.654      0.463      0.495       0.41
# acanthocybium_solandri          3          9      0.513      0.111       0.32      0.161
#       alectis_ciliaris          2          4      0.758       0.25      0.432      0.399
#      aphareus_rutilans          1          1      0.451          1      0.995      0.995
#   aurigequula_fasciata          4          4      0.232       0.25     0.0943     0.0802
#       caranx_ignobilis          5         10      0.611        0.5      0.545      0.442
#      caranx_melampygus          3          3       0.85          1      0.995      0.887
#     chirocentrus_dorab          2          2          0          0          0          0
#  decapterus_macarellus          2         12          1      0.772       0.84      0.519
#   decapterus_macrosoma          1          1      0.737          1      0.995      0.497
#   elagatis_bipinnulata          2          2      0.842          1      0.995      0.923
#  epinephelus_maculatus          4          4      0.865          1      0.995      0.895
#   epinephelus_radiatus          1          1      0.324          1      0.332      0.265
#     etelis_carbunculus          3          3      0.881      0.667      0.913      0.759
#           gazza_minuta          6          6      0.699      0.781      0.755      0.704
# gymnocranius_grandoculis          2          2      0.245        0.5      0.201      0.163
#     katsuwonus_pelamis          1          1      0.407          1      0.995      0.796
#      lethrinus_mahsena          1          1          1          0     0.0829     0.0663
#         lujanus_gibbus          1         14      0.807      0.896      0.919      0.744
#   lutjanus_fulviflamma          4         13          1          0      0.122      0.112
#        lutjanus_fulvus          2          2      0.625      0.876      0.663      0.614
#        lutjanus_johnii          4         10       0.99        0.7       0.74      0.626
#     lutjanus_russellii          1          1          0          0          0          0
#  monotaxis_grandoculis          2          2          1          0          0          0
# mulloidichtys_vanicolensis          1          6      0.189      0.333      0.235      0.212
# plectorhinchus_vittatus          1          1          1          0          0          0
#    pomadasys_argenteus          3          3          0          0     0.0753     0.0657
#       pomadasys_kaakan          2          3      0.274      0.667      0.693      0.659
#   pristigenys_niphonia          2          6      0.682      0.167      0.357      0.283
# pseudobalistes_flavimarginatus          2          2          1          0      0.516      0.516
# rastrelliger_kanagurta          4         46          1          0      0.155     0.0726
#     sardinella_albella          2          2          1          0      0.114      0.103
#       scomberoides_tol          5         12      0.918      0.167      0.266      0.224
#         siganus_spinus          1          1          0          0          0          0
#       upeneus_vittatus          3          3          1      0.813      0.995      0.681
#  variola_albimarginata          2          2          1      0.768      0.995      0.895
# Speed: 0.2ms preprocess, 0.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\train6
# Ultralytics 8.3.235  Python-3.12.10 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO11n summary (fused): 100 layers, 2,609,800 parameters, 0 gradients, 7.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 330.7189.9 MB/s, size: 16.7 KB)
# val: Scanning C:\Users\kienn\Downloads\Prosjektoppgave\yolo\full_dataset\valid\labels.cache... 208 images, 124 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 208/208 208.0Kit/s 0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 176, len(boxes) = 195. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 14.7it/s 0.9s0.1s
#                    all        208        195      0.613      0.458      0.496      0.409
# acanthocybium_solandri          3          9       0.53      0.111      0.338      0.168
#       alectis_ciliaris          2          4      0.765       0.25      0.433      0.399
#      aphareus_rutilans          1          1      0.455          1      0.995      0.995
#   aurigequula_fasciata          4          4      0.233       0.25     0.0932     0.0794
#       caranx_ignobilis          5         10      0.602      0.456      0.553      0.449
#      caranx_melampygus          3          3       0.86          1      0.995      0.903
#     chirocentrus_dorab          2          2          0          0          0          0
#  decapterus_macarellus          2         12          1      0.768      0.841      0.503
#   decapterus_macrosoma          1          1      0.739          1      0.995      0.497
#   elagatis_bipinnulata          2          2      0.848          1      0.995      0.923
#  epinephelus_maculatus          4          4      0.866          1      0.995      0.895
#   epinephelus_radiatus          1          1      0.317          1      0.332      0.265
#     etelis_carbunculus          3          3      0.893      0.667      0.913      0.759
#           gazza_minuta          6          6      0.714      0.831      0.755      0.693
# gymnocranius_grandoculis          2          2      0.247        0.5      0.195      0.158
#     katsuwonus_pelamis          1          1       0.41          1      0.995      0.796
#      lethrinus_mahsena          1          1          0          0     0.0995     0.0796
#         lujanus_gibbus          1         14      0.803      0.875      0.919      0.743
#   lutjanus_fulviflamma          4         13          1          0      0.151      0.129
#        lutjanus_fulvus          2          2      0.599      0.798      0.663      0.614
#        lutjanus_johnii          4         10      0.994        0.7      0.738      0.625
#     lutjanus_russellii          1          1          0          0          0          0
#  monotaxis_grandoculis          2          2          1          0          0          0
# mulloidichtys_vanicolensis          1          6      0.209      0.333      0.235      0.212
# plectorhinchus_vittatus          1          1          1          0          0          0
#    pomadasys_argenteus          3          3          0          0     0.0702     0.0612
#       pomadasys_kaakan          2          3      0.275      0.667      0.692      0.658
#   pristigenys_niphonia          2          6      0.699      0.167      0.404      0.306
# pseudobalistes_flavimarginatus          2          2          1          0      0.516      0.516
# rastrelliger_kanagurta          4         46          1          0      0.151     0.0694
#     sardinella_albella          2          2          1          0     0.0975     0.0878
#       scomberoides_tol          5         12      0.402     0.0833      0.224      0.191
#         siganus_spinus          1          1          0          0          0          0
#       upeneus_vittatus          3          3          1      0.807      0.995      0.681
#  variola_albimarginata          2          2          1      0.759      0.995       0.85
# Speed: 0.4ms preprocess, 2.4ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to C:\Users\kienn\Downloads\Prosjektoppgave\yolo\runs\detect\val3

# %%
import pandas as pd
import pathlib
import ast
import re

# ----------------- USER ADJUSTABLE VARIABLES -----------------
# Provide GT (path or DataFrame). Example uses your variable name:
gt_input = pd.read_csv(timor_leste_data_path, encoding="utf-8-sig", header=0, skiprows=1)

# Predictions CSV path or DataFrame
preds_input = "predictions_with_groundtruth_matches.csv"

# Column names used in your files
gt_image_col = "image_file"
gt_species_col = "Species_name"
preds_image_col = "image_file"
preds_class_col = "pred_class"   # one-row-per-detection format (optional)
preds_list_col = "pred_list"     # one-row-per-image list column (optional)

# Choose Title case for predictions
PRED_CASE = "title"
# ------------------------------------------------------------

# ----------------- Helper functions -----------------
def title_case_name(s):
    """Return string in 'Genus species' style: Genus capitalized, rest lowercased."""
    if s is None:
        return ""
    s = str(s).strip()
    # collapse whitespace and separators
    s = re.sub(r"[ _\-\.\s]+", " ", s).strip()
    parts = s.split()
    if len(parts) >= 2:
        return parts[0].capitalize() + " " + " ".join(p.lower() for p in parts[1:])
    return s.capitalize()

def normalize_label_title(x):
    """Normalize input to Title Case for consistent comparison."""
    if pd.isna(x):
        return ""
    return title_case_name(x)

def snake_or_token_to_name(token: str, case="title"):
    """Convert tokens like 'scomberomorus_commerson' to Title Case or raw string."""
    if token is None:
        return ""
    s = str(token).strip().strip("'\"")
    s = re.sub(r"[ _\-\.\s]+", " ", s).strip()
    if case == "lower":
        return s.lower()
    if case == "title":
        return title_case_name(s)
    return s

def parse_pred_list_cell(val, case="title"):
    """
    Robust parse for pred list cells -> returns list of converted labels in chosen case.
    """
    if val is None or (isinstance(val, float) and pd.isna(val)):
        return []
    if isinstance(val, (list, tuple)):
        return [snake_or_token_to_name(x, case=case) for x in val]
    s = str(val).strip()
    # try safe literal eval
    if s.startswith("[") and s.endswith("]"):
        try:
            parsed = ast.literal_eval(s)
            if isinstance(parsed, (list, tuple)):
                return [snake_or_token_to_name(x, case=case) for x in parsed]
        except Exception:
            pass
    # separators
    if "|" in s:
        parts = [p.strip() for p in s.split("|") if p.strip()]
        return [snake_or_token_to_name(x, case=case) for x in parts]
    if "," in s:
        parts = [p.strip() for p in s.split(",") if p.strip()]
        return [snake_or_token_to_name(x, case=case) for x in parts]
    return [snake_or_token_to_name(s, case=case)]

# ----------------- Load inputs -----------------
def load_gt(gt_input):
    if isinstance(gt_input, pd.DataFrame):
        return gt_input.copy()
    if isinstance(gt_input, (str, pathlib.Path)):
        return pd.read_csv(str(gt_input))
    if hasattr(gt_input, "read") and callable(getattr(gt_input, "read")):
        return pd.read_csv(gt_input)
    raise TypeError("gt_input must be a DataFrame, filename (str/Path), or file-like object.")

def load_preds(preds_input):
    if isinstance(preds_input, pd.DataFrame):
        return preds_input.copy()
    if isinstance(preds_input, (str, pathlib.Path)):
        return pd.read_csv(str(preds_input))
    if hasattr(preds_input, "read") and callable(getattr(preds_input, "read")):
        return pd.read_csv(preds_input)
    raise TypeError("preds_input must be a DataFrame, filename (str/Path), or file-like object.")

gt = load_gt(gt_input)
preds_df = load_preds(preds_input)

# Normalize image filename columns
gt[gt_image_col] = gt[gt_image_col].astype(str).str.strip()
preds_df[preds_image_col] = preds_df[preds_image_col].astype(str).str.strip()

# ----------------- Prepare ground-truth lists (Title Case) -----------------
def split_gt_species(s):
    if pd.isna(s):
        return []
    s = str(s)
    for sep in [" & ", "&", "/", ";", ",", "|"]:
        s = s.replace(sep, " | ")
    parts = [p.strip() for p in s.split("|") if p.strip()]
    return parts

gt["gt_list"] = gt[gt_species_col].apply(split_gt_species)
# Normalize GT list to Title Case
gt["gt_norm_list"] = gt["gt_list"].apply(lambda lst: [normalize_label_title(x) for x in lst])

# ----------------- Prepare predictions grouped per image (converted to Title Case) -----------------
if preds_class_col in preds_df.columns:
    # convert token labels in pred_class directly to Title Case, then group
    preds_df["_pred_converted"] = preds_df[preds_class_col].apply(lambda v: snake_or_token_to_name(v, case=PRED_CASE))
    preds_grouped = preds_df.groupby(preds_image_col)["_pred_converted"].apply(list).reset_index()
    preds_grouped.columns = [preds_image_col, "predicted_list"]
elif preds_list_col in preds_df.columns:
    preds_grouped = preds_df[[preds_image_col, preds_list_col]].copy()
    preds_grouped["predicted_list"] = preds_grouped[preds_list_col].apply(lambda v: parse_pred_list_cell(v, case=PRED_CASE))
    preds_grouped = preds_grouped[[preds_image_col, "predicted_list"]]
else:
    # fallback search for commonly named columns
    fallback_names = ["predicted_list", "predictions", "preds"]
    found = False
    for name in fallback_names:
        if name in preds_df.columns:
            preds_grouped = preds_df[[preds_image_col, name]].copy()
            preds_grouped["predicted_list"] = preds_grouped[name].apply(lambda v: parse_pred_list_cell(v, case=PRED_CASE))
            preds_grouped = preds_grouped[[preds_image_col, "predicted_list"]]
            found = True
            break
    if not found:
        raise ValueError(f"Predictions must contain either '{preds_class_col}' or '{preds_list_col}' or one of {fallback_names}.")

# ----------------- Merge and compute matches -----------------
merged = pd.merge(
    gt[[gt_image_col, gt_species_col, "gt_list", "gt_norm_list"]],
    preds_grouped,
    how="left",
    left_on=gt_image_col,
    right_on=preds_image_col
)

# ensure predicted_list is a real list
merged["predicted_list"] = merged["predicted_list"].apply(lambda x: x if isinstance(x, list) else ([] if pd.isna(x) else list(x)))
# Normalize predicted labels to Title Case for preds_norm (ensures Title)
merged["preds_norm"] = merged["predicted_list"].apply(lambda lst: [normalize_label_title(p) for p in lst])

def any_match(gt_norm_list, preds_norm_list):
    if not gt_norm_list:
        return False
    return any((g == p) for g in gt_norm_list for p in preds_norm_list)

merged["match_any"] = merged.apply(lambda r: any_match(r["gt_norm_list"], r["preds_norm"]), axis=1)
merged["n_predictions"] = merged["preds_norm"].apply(len)
merged["multi_predictions"] = merged["n_predictions"] > 1
merged["zero_predictions"] = merged["n_predictions"] == 0

def first_matching_pred(gt_norm_list, preds_norm_list, preds_orig_list):
    for p_norm, p_orig in zip(preds_norm_list, preds_orig_list):
        if any(p_norm == g for g in gt_norm_list):
            return p_orig
    return None

merged["matching_pred"] = merged.apply(lambda r: first_matching_pred(r["gt_norm_list"], r["preds_norm"], r["predicted_list"]), axis=1)

# ----------------- Outputs & summary -----------------
match_flag_series = merged[[gt_image_col, "match_any"]].copy()
multi_pred_filenames = merged.loc[merged["multi_predictions"], gt_image_col].tolist()
zero_pred_filenames = merged.loc[merged["zero_predictions"], gt_image_col].tolist()

total = len(merged)
num_matches = int(merged["match_any"].sum())
pct = num_matches / total * 100 if total > 0 else 0.0

print(f"Total GT rows: {total}")
print(f"Images with >=1 matching prediction: {num_matches} ({pct:.2f}%)")
print(f"Images with multiple predictions (>1): {merged['multi_predictions'].sum()}")
print(f"Images with zero predictions: {merged['zero_predictions'].sum()}")

# quick sanity-check: show a few rows and their normalized columns
print("\nExample rows (image_file, gt_norm_list, predicted_list, preds_norm, match_any):")
print(merged[[gt_image_col, "gt_norm_list", "predicted_list", "preds_norm", "match_any"]].head(10).to_string(index=False))

# Save full analysis for inspection
out_csv = "gt_vs_preds_analysis_converted_title.csv"
merged.to_csv(out_csv, index=False)
print(f"\nSaved analysis to: {out_csv}")

# Expose variables for further use: merged, match_flag_series, multi_pred_filenames, zero_pred_filenames
# Out:
# Total GT rows: 603
# Images with >=1 matching prediction: 13 (2.16%)
# Images with multiple predictions (>1): 142
# Images with zero predictions: 284
#
# Example rows (image_file, gt_norm_list, predicted_list, preds_norm, match_any):
#        image_file           gt_norm_list        predicted_list            preds_norm  match_any
# 1689120590238.jpg  [Caranx sexfasciatus]                 [Nan]                 [Nan]      False
# 1689254343092.jpg         [Gazza minuta]            [Nan, Nan]            [Nan, Nan]      False
# 1689254343092.jpg     [Upeneus vittatus]            [Nan, Nan]            [Nan, Nan]      False
# 1689379821579.jpg           [Decapterus]                    []                    []      False
# 1689388044927.jpg      [Caranx lugubris] [Pomadasys argenteus] [Pomadasys argenteus]      False
# 1689388326411.jpg      [Caranx lugubris]  [Parupeneus indicus]  [Parupeneus indicus]      False
# 1689421223571.jpg [Rastrelliger faughni]                    []                    []      False
# 1689556573003.jpg [Rastrelliger faughni]                    []                    []      False
# 1689556897897.jpg [Rastrelliger faughni]                    []                    []      False
# 1689557063983.jpg [Lutjanus timoriensis]                    []                    []      False
#
# Saved analysis to: gt_vs_preds_analysis_converted_title.csv

# %%
import pandas as pd
import pathlib
import ast
import re

# ----------------- USER ADJUSTABLE VARIABLES -----------------
# Provide GT (path or DataFrame). Example uses your variable name:
gt_input = pd.read_csv(timor_leste_data_path, encoding="utf-8-sig", header=0, skiprows=1)

# Predictions CSV path or DataFrame
preds_input = "predictions_with_groundtruth_matches.csv"

# Column names used in your files
gt_image_col = "image_file"
gt_species_col = "Species_name"
preds_image_col = "image_file"
preds_class_col = "pred_class"   # one-row-per-detection format (optional)
preds_list_col = "pred_list"     # one-row-per-image list column (optional)

# Choose Title case for predictions
PRED_CASE = "title"
# ------------------------------------------------------------

# ----------------- Helper functions -----------------
def title_case_name(s):
    """Return string in 'Genus species' style: Genus capitalized, rest lowercased."""
    if s is None:
        return ""
    s = str(s).strip()
    # collapse whitespace and separators
    s = re.sub(r"[ _\-\.\s]+", " ", s).strip()
    parts = s.split()
    if len(parts) >= 2:
        return parts[0].capitalize() + " " + " ".join(p.lower() for p in parts[1:])
    return s.capitalize()

def normalize_label_title(x):
    """Normalize input to Title Case for consistent comparison."""
    if pd.isna(x):
        return ""
    return title_case_name(x)

def snake_or_token_to_name(token: str, case="title"):
    """Convert tokens like 'scomberomorus_commerson' to Title Case or raw string."""
    if token is None:
        return ""
    s = str(token).strip().strip("'\"")
    s = re.sub(r"[ _\-\.\s]+", " ", s).strip()
    if case == "lower":
        return s.lower()
    if case == "title":
        return title_case_name(s)
    return s

def parse_pred_list_cell(val, case="title"):
    """
    Robust parse for pred list cells -> returns list of converted labels in chosen case.
    """
    if val is None or (isinstance(val, float) and pd.isna(val)):
        return []
    if isinstance(val, (list, tuple)):
        return [snake_or_token_to_name(x, case=case) for x in val]
    s = str(val).strip()
    # try safe literal eval
    if s.startswith("[") and s.endswith("]"):
        try:
            parsed = ast.literal_eval(s)
            if isinstance(parsed, (list, tuple)):
                return [snake_or_token_to_name(x, case=case) for x in parsed]
        except Exception:
            pass
    # separators
    if "|" in s:
        parts = [p.strip() for p in s.split("|") if p.strip()]
        return [snake_or_token_to_name(x, case=case) for x in parts]
    if "," in s:
        parts = [p.strip() for p in s.split(",") if p.strip()]
        return [snake_or_token_to_name(x, case=case) for x in parts]
    return [snake_or_token_to_name(s, case=case)]

# ----------------- Load inputs -----------------
def load_gt(gt_input):
    if isinstance(gt_input, pd.DataFrame):
        return gt_input.copy()
    if isinstance(gt_input, (str, pathlib.Path)):
        return pd.read_csv(str(gt_input))
    if hasattr(gt_input, "read") and callable(getattr(gt_input, "read")):
        return pd.read_csv(gt_input)
    raise TypeError("gt_input must be a DataFrame, filename (str/Path), or file-like object.")

def load_preds(preds_input):
    if isinstance(preds_input, pd.DataFrame):
        return preds_input.copy()
    if isinstance(preds_input, (str, pathlib.Path)):
        return pd.read_csv(str(preds_input))
    if hasattr(preds_input, "read") and callable(getattr(preds_input, "read")):
        return pd.read_csv(preds_input)
    raise TypeError("preds_input must be a DataFrame, filename (str/Path), or file-like object.")

gt = load_gt(gt_input)
preds_df = load_preds(preds_input)

# Normalize image filename columns
gt[gt_image_col] = gt[gt_image_col].astype(str).str.strip()
preds_df[preds_image_col] = preds_df[preds_image_col].astype(str).str.strip()

# ----------------- Prepare ground-truth lists (Title Case) -----------------
def split_gt_species(s):
    if pd.isna(s):
        return []
    s = str(s)
    for sep in [" & ", "&", "/", ";", ",", "|"]:
        s = s.replace(sep, " | ")
    parts = [p.strip() for p in s.split("|") if p.strip()]
    return parts

gt["gt_list"] = gt[gt_species_col].apply(split_gt_species)
# Normalize GT list to Title Case
gt["gt_norm_list"] = gt["gt_list"].apply(lambda lst: [normalize_label_title(x) for x in lst])

# ----------------- Prepare predictions grouped per image (converted to Title Case) -----------------
if preds_class_col in preds_df.columns:
    # convert token labels in pred_class directly to Title Case, then group
    preds_df["_pred_converted"] = preds_df[preds_class_col].apply(lambda v: snake_or_token_to_name(v, case=PRED_CASE))
    preds_grouped = preds_df.groupby(preds_image_col)["_pred_converted"].apply(list).reset_index()
    preds_grouped.columns = [preds_image_col, "predicted_list"]
elif preds_list_col in preds_df.columns:
    preds_grouped = preds_df[[preds_image_col, preds_list_col]].copy()
    preds_grouped["predicted_list"] = preds_grouped[preds_list_col].apply(lambda v: parse_pred_list_cell(v, case=PRED_CASE))
    preds_grouped = preds_grouped[[preds_image_col, "predicted_list"]]
else:
    # fallback search for commonly named columns
    fallback_names = ["predicted_list", "predictions", "preds"]
    found = False
    for name in fallback_names:
        if name in preds_df.columns:
            preds_grouped = preds_df[[preds_image_col, name]].copy()
            preds_grouped["predicted_list"] = preds_grouped[name].apply(lambda v: parse_pred_list_cell(v, case=PRED_CASE))
            preds_grouped = preds_grouped[[preds_image_col, "predicted_list"]]
            found = True
            break
    if not found:
        raise ValueError(f"Predictions must contain either '{preds_class_col}' or '{preds_list_col}' or one of {fallback_names}.")

# ----------------- Merge and compute matches -----------------
merged = pd.merge(
    gt[[gt_image_col, gt_species_col, "gt_list", "gt_norm_list"]],
    preds_grouped,
    how="left",
    left_on=gt_image_col,
    right_on=preds_image_col
)

# ensure predicted_list is a real list
merged["predicted_list"] = merged["predicted_list"].apply(lambda x: x if isinstance(x, list) else ([] if pd.isna(x) else list(x)))
# Normalize predicted labels to Title Case for preds_norm (ensures Title)
merged["preds_norm"] = merged["predicted_list"].apply(lambda lst: [normalize_label_title(p) for p in lst])

def any_match(gt_norm_list, preds_norm_list):
    if not gt_norm_list:
        return False
    return any((g == p) for g in gt_norm_list for p in preds_norm_list)

merged["match_any"] = merged.apply(lambda r: any_match(r["gt_norm_list"], r["preds_norm"]), axis=1)
merged["n_predictions"] = merged["preds_norm"].apply(len)
merged["multi_predictions"] = merged["n_predictions"] > 1
merged["zero_predictions"] = merged["n_predictions"] == 0

def first_matching_pred(gt_norm_list, preds_norm_list, preds_orig_list):
    for p_norm, p_orig in zip(preds_norm_list, preds_orig_list):
        if any(p_norm == g for g in gt_norm_list):
            return p_orig
    return None

merged["matching_pred"] = merged.apply(lambda r: first_matching_pred(r["gt_norm_list"], r["preds_norm"], r["predicted_list"]), axis=1)

# ----------------- Outputs & summary -----------------
match_flag_series = merged[[gt_image_col, "match_any"]].copy()
multi_pred_filenames = merged.loc[merged["multi_predictions"], gt_image_col].tolist()
zero_pred_filenames = merged.loc[merged["zero_predictions"], gt_image_col].tolist()

total = len(merged)
num_matches = int(merged["match_any"].sum())
pct = num_matches / total * 100 if total > 0 else 0.0

print(f"Total GT rows: {total}")
print(f"Images with >=1 matching prediction: {num_matches} ({pct:.2f}%)")
print(f"Images with multiple predictions (>1): {merged['multi_predictions'].sum()}")
print(f"Images with zero predictions: {merged['zero_predictions'].sum()}")

# quick sanity-check: show a few rows and their normalized columns
print("\nExample rows (image_file, gt_norm_list, predicted_list, preds_norm, match_any):")
print(merged[[gt_image_col, "gt_norm_list", "predicted_list", "preds_norm", "match_any"]].head(10).to_string(index=False))

# Save full analysis for inspection
out_csv = "gt_vs_preds_analysis_converted_title.csv"
merged.to_csv(out_csv, index=False)
print(f"\nSaved analysis to: {out_csv}")

# Expose variables for further use: merged, match_flag_series, multi_pred_filenames, zero_pred_filenames
# Out:
# Total GT rows: 603
# Images with >=1 matching prediction: 13 (2.16%)
# Images with multiple predictions (>1): 142
# Images with zero predictions: 284
#
# Example rows (image_file, gt_norm_list, predicted_list, preds_norm, match_any):
#        image_file           gt_norm_list        predicted_list            preds_norm  match_any
# 1689120590238.jpg  [Caranx sexfasciatus]                 [Nan]                 [Nan]      False
# 1689254343092.jpg         [Gazza minuta]            [Nan, Nan]            [Nan, Nan]      False
# 1689254343092.jpg     [Upeneus vittatus]            [Nan, Nan]            [Nan, Nan]      False
# 1689379821579.jpg           [Decapterus]                    []                    []      False
# 1689388044927.jpg      [Caranx lugubris] [Pomadasys argenteus] [Pomadasys argenteus]      False
# 1689388326411.jpg      [Caranx lugubris]  [Parupeneus indicus]  [Parupeneus indicus]      False
# 1689421223571.jpg [Rastrelliger faughni]                    []                    []      False
# 1689556573003.jpg [Rastrelliger faughni]                    []                    []      False
# 1689556897897.jpg [Rastrelliger faughni]                    []                    []      False
# 1689557063983.jpg [Lutjanus timoriensis]                    []                    []      False
#
# Saved analysis to: gt_vs_preds_analysis_converted_title.csv

# %%
display(Image(filename="runs/detect/train6/results.png"))
display(Image(filename="runs/detect/val3/confusion_matrix.png"))

# %%
import os
import pandas as pd
from ultralytics import YOLO

# ---------- config ----------
MODEL_PATH = "runs/detect/train6/weights/best.pt"
IMAGE_PATHS = [os.path.join("../data_images/", f) for f in filtered_images]  # filtered_images must exist
CSV_OUT = "predictions_with_groundtruth_matches.csv"
GT_FILENAME_COL = "image_file"          # column in df_tl_ann to join on
GT_SPECIES_COL = "Species_name"       # ground truth species column name in df_tl_ann
# ----------------------------

# Load model
model = YOLO(MODEL_PATH)

# Run predictions (you can tune imgsz, conf, etc.)
results = model.predict(source=IMAGE_PATHS, imgsz=480)

# Build predictions dataframe
pred_rows = []
for r in results:
    image_name = os.path.basename(r.path)
    boxes = getattr(r, "boxes", None)

    if boxes is None or len(boxes) == 0:
        pred_rows.append({
            "image_file": image_name,
            "pred_class": None,
            "pred_conf": None,
            "pred_x1": None,
            "pred_y1": None,
            "pred_x2": None,
            "pred_y2": None,
        })
        continue

    xyxy = boxes.xyxy.cpu().numpy()
    scores = boxes.conf.cpu().numpy()
    classes = boxes.cls.cpu().numpy()

    for (x1, y1, x2, y2), conf, cls in zip(xyxy, scores, classes):
        pred_rows.append({
            "image_file": image_name,
            "pred_class": model.names[int(cls)] if cls is not None else None,
            "pred_conf": float(conf),
            "pred_x1": int(x1),
            "pred_y1": int(y1),
            "pred_x2": int(x2),
            "pred_y2": int(y2),
        })

df_preds = pd.DataFrame(pred_rows)

# ---------- load ground truth ----------
# If df_tl_ann is not already loaded, load it here, e.g.:
# df_tl_ann = pd.read_csv("timor_leste_annotations.csv")
# Ensure it contains the expected columns
if GT_FILENAME_COL not in df_tl_ann.columns:
    raise KeyError(f"Ground truth dataframe must contain column '{GT_FILENAME_COL}'")
if GT_SPECIES_COL not in df_tl_ann.columns:
    raise KeyError(f"Ground truth dataframe must contain species column '{GT_SPECIES_COL}'")

# If ground truth has multiple rows per filename (multiple labeled fish per image),
# aggregate species into a list per filename to allow matching any of them.
df_gt_grouped = (
    df_tl_ann
    .groupby(GT_FILENAME_COL)[GT_SPECIES_COL]
    .apply(lambda s: list(s.dropna().astype(str)))
    .reset_index()
    .rename(columns={GT_SPECIES_COL: "gt_species_list"})
)

# Merge predictions with grouped ground truth (left join keeps predictions even if no GT)
df_merged = df_preds.merge(df_gt_grouped, on="image_file", how="left")

# ---------- helper for normalization ----------
def normalize_name(s):
    if pd.isna(s) or s is None:
        return ""
    # lowercase, strip whitespace, replace underscores, collapse multiple spaces
    s2 = str(s).lower().strip().replace("_", " ")
    s2 = " ".join(s2.split())
    return s2

# Normalize GT species lists & prediction class for comparison
df_merged["pred_class_norm"] = df_merged["pred_class"].apply(normalize_name)
df_merged["gt_species_norm_list"] = df_merged["gt_species_list"].apply(
    lambda lst: [normalize_name(x) for x in lst] if isinstance(lst, list) else []
)

# ---------- compute match column ----------
def compare_row(row):
    pred = row["pred_class_norm"]
    gt_list = row["gt_species_norm_list"]

    if (pred == "" or pred is None) and (not gt_list):
        # no detection and no gt
        return "NO_DETECTION_AND_NO_GT"
    if pred == "" or pred is None:
        # no detection but GT exists
        return "NO_DETECTION"
    if not gt_list:
        # prediction exists but no ground truth
        return "NO_GT"
    # if any exact match in normalized strings:
    if pred in gt_list:
        return "MATCH"
    # optionally: fuzzy matching can be done here (e.g., substring/in operator)
    # try substring match (pred contained in any gt or vice versa)
    for g in gt_list:
        if pred in g or g in pred:
            return "MATCH_SUBSTRING"
    return "MISMATCH"

df_merged["match"] = df_merged.apply(compare_row, axis=1)

summary = df_merged["match"].value_counts(dropna=False)
print("Match summary:\n", summary)

# Save to CSV
df_merged.to_csv(CSV_OUT, index=False)
print(f"\nSaved merged file with matches to: {CSV_OUT}")
# Out:
# 0: 480x480 (no detections), 0.8ms
# 1: 480x480 (no detections), 0.8ms
# 2: 480x480 (no detections), 0.8ms
# 3: 480x480 1 pomadasys_argenteus, 0.8ms
# 4: 480x480 1 parupeneus_indicus, 0.8ms
# 5: 480x480 7 chirocentrus_dorabs, 0.8ms
# 6: 480x480 1 chirocentrus_dorab, 0.8ms
# 7: 480x480 1 chirocentrus_dorab, 0.8ms
# 8: 480x480 (no detections), 0.8ms
# 9: 480x480 (no detections), 0.8ms
# 10: 480x480 (no detections), 0.8ms
# 11: 480x480 1 acanthocybium_solandri, 1 scomberomorus_commerson, 0.8ms
# 12: 480x480 1 acanthocybium_solandri, 0.8ms
# 13: 480x480 1 alectis_ciliaris, 0.8ms
# 14: 480x480 2 chirocentrus_dorabs, 0.8ms
# 15: 480x480 (no detections), 0.8ms
# 16: 480x480 1 chirocentrus_dorab, 0.8ms
# 17: 480x480 1 chirocentrus_dorab, 0.8ms
# 18: 480x480 1 chirocentrus_dorab, 0.8ms
# 19: 480x480 1 chirocentrus_dorab, 0.8ms
# 20: 480x480 1 caranx_ignobilis, 0.8ms
# 21: 480x480 1 chirocentrus_dorab, 0.8ms
# 22: 480x480 1 caranx_ignobilis, 0.8ms
# 23: 480x480 1 scomberomorus_commerson, 0.8ms
# 24: 480x480 1 scomberomorus_commerson, 0.8ms
# 25: 480x480 (no detections), 0.8ms
# 26: 480x480 (no detections), 0.8ms
# 27: 480x480 (no detections), 0.8ms
# 28: 480x480 1 aurigequula_fasciata, 5 gazza_minutas, 0.8ms
# 29: 480x480 1 aurigequula_fasciata, 5 gazza_minutas, 0.8ms
# 30: 480x480 1 scomberoides_tol, 0.8ms
# 31: 480x480 6 scomberoides_tols, 0.8ms
# 32: 480x480 6 scomberoides_tols, 0.8ms
# 33: 480x480 1 lutjanus_johnii, 2 parupeneus_heptacanthuss, 0.8ms
# 34: 480x480 1 gazza_minuta, 1 parupeneus_heptacanthus, 0.8ms
# 35: 480x480 1 gazza_minuta, 1 parupeneus_heptacanthus, 0.8ms
# 36: 480x480 1 scomberomorus_commerson, 0.8ms
# 37: 480x480 1 scomberomorus_commerson, 0.8ms
# 38: 480x480 2 chirocentrus_dorabs, 0.8ms
# 39: 480x480 1 scomberomorus_commerson, 0.8ms
# 40: 480x480 1 scomberomorus_commerson, 0.8ms
# 41: 480x480 (no detections), 0.8ms
# 42: 480x480 (no detections), 0.8ms
# 43: 480x480 1 aurigequula_fasciata, 0.8ms
# 44: 480x480 5 gazza_minutas, 0.8ms
# 45: 480x480 5 gazza_minutas, 0.8ms
# 46: 480x480 (no detections), 0.8ms
# 47: 480x480 (no detections), 0.8ms
# 48: 480x480 (no detections), 0.8ms
# 49: 480x480 (no detections), 0.8ms
# 50: 480x480 1 chirocentrus_dorab, 0.8ms
# 51: 480x480 1 pomadasys_argenteus, 0.8ms
# 52: 480x480 1 scomberomorus_commerson, 0.8ms
# 53: 480x480 (no detections), 0.8ms
# 54: 480x480 1 pomadasys_kaakan, 0.8ms
# 55: 480x480 1 scomberomorus_commerson, 0.8ms
# 56: 480x480 1 scomberomorus_commerson, 0.8ms
# 57: 480x480 1 lutjanus_johnii, 1 rastrelliger_kanagurta, 0.8ms
# 58: 480x480 1 lutjanus_johnii, 1 rastrelliger_kanagurta, 0.8ms
# 59: 480x480 1 lutjanus_johnii, 1 rastrelliger_kanagurta, 0.8ms
# 60: 480x480 (no detections), 0.8ms
# 61: 480x480 1 gazza_minuta, 0.8ms
# 62: 480x480 1 gazza_minuta, 0.8ms
# 63: 480x480 2 pomadasys_argenteuss, 2 pomadasys_kaakans, 0.8ms
# 64: 480x480 1 lutjanus_johnii, 1 pomadasys_argenteus, 0.8ms
# 65: 480x480 1 lutjanus_johnii, 1 pomadasys_argenteus, 0.8ms
# 66: 480x480 (no detections), 0.8ms
# 67: 480x480 1 gazza_minuta, 0.8ms
# 68: 480x480 1 caranx_ignobilis, 0.8ms
# 69: 480x480 2 scomberoides_tols, 0.8ms
# 70: 480x480 (no detections), 0.8ms
# 71: 480x480 4 chirocentrus_dorabs, 1 scomberoides_tol, 0.8ms
# 72: 480x480 1 acanthocybium_solandri, 3 scomberomorus_commersons, 0.8ms
# 73: 480x480 (no detections), 0.8ms
# 74: 480x480 (no detections), 0.8ms
# 75: 480x480 1 scomberomorus_commerson, 0.8ms
# 76: 480x480 1 scomberomorus_commerson, 0.8ms
# 77: 480x480 (no detections), 0.8ms
# 78: 480x480 (no detections), 0.8ms
# 79: 480x480 1 chirocentrus_dorab, 3 scomberomorus_commersons, 0.8ms
# 80: 480x480 (no detections), 0.8ms
# 81: 480x480 1 alectis_ciliaris, 0.8ms
# 82: 480x480 1 alectis_ciliaris, 0.8ms
# 83: 480x480 1 aurigequula_fasciata, 0.8ms
# 84: 480x480 2 lutjanus_johniis, 0.8ms
# 85: 480x480 (no detections), 0.8ms
# 86: 480x480 1 aurigequula_fasciata, 0.8ms
# 87: 480x480 (no detections), 0.8ms
# 88: 480x480 1 caranx_ignobilis, 0.8ms
# 89: 480x480 1 caranx_ignobilis, 0.8ms
# 90: 480x480 1 chirocentrus_dorab, 0.8ms
# 91: 480x480 1 alectis_ciliaris, 0.8ms
# 92: 480x480 1 alectis_ciliaris, 0.8ms
# 93: 480x480 1 chirocentrus_dorab, 0.8ms
# 94: 480x480 1 scomberomorus_commerson, 0.8ms
# 95: 480x480 1 alectis_ciliaris, 0.8ms
# 96: 480x480 1 alectis_ciliaris, 1 caranx_ignobilis, 0.8ms
# 97: 480x480 1 chirocentrus_dorab, 0.8ms
# 98: 480x480 (no detections), 0.8ms
# 99: 480x480 1 aurigequula_fasciata, 0.8ms
# 100: 480x480 1 chirocentrus_dorab, 0.8ms
# 101: 480x480 1 chirocentrus_dorab, 5 scomberomorus_commersons, 0.8ms
# 102: 480x480 1 chirocentrus_dorab, 0.8ms
# 103: 480x480 (no detections), 0.8ms
# 104: 480x480 1 scomberomorus_commerson, 0.8ms
# 105: 480x480 (no detections), 0.8ms
# 106: 480x480 (no detections), 0.8ms
# 107: 480x480 1 pomadasys_argenteus, 0.8ms
# 108: 480x480 1 decapterus_macarellus, 0.8ms
# 109: 480x480 (no detections), 0.8ms
# 110: 480x480 1 chirocentrus_dorab, 0.8ms
# 111: 480x480 1 chirocentrus_dorab, 0.8ms
# 112: 480x480 1 caranx_ignobilis, 1 scomberoides_tol, 0.8ms
# 113: 480x480 (no detections), 0.8ms
# 114: 480x480 1 pomadasys_argenteus, 0.8ms
# 115: 480x480 (no detections), 0.8ms
# 116: 480x480 (no detections), 0.8ms
# 117: 480x480 1 alectis_ciliaris, 1 caranx_melampygus, 1 chirocentrus_dorab, 0.8ms
# 118: 480x480 1 alectis_ciliaris, 1 caranx_melampygus, 1 chirocentrus_dorab, 0.8ms
# 119: 480x480 (no detections), 0.8ms
# 120: 480x480 (no detections), 0.8ms
# 121: 480x480 (no detections), 0.8ms
# 122: 480x480 (no detections), 0.8ms
# 123: 480x480 (no detections), 0.8ms
# 124: 480x480 (no detections), 0.8ms
# 125: 480x480 1 gazza_minuta, 1 lujanus_gibbus, 0.8ms
# 126: 480x480 (no detections), 0.8ms
# 127: 480x480 2 pomadasys_argenteuss, 0.8ms
# 128: 480x480 2 pomadasys_argenteuss, 0.8ms
# 129: 480x480 2 pomadasys_argenteuss, 0.8ms
# 130: 480x480 2 pomadasys_argenteuss, 0.8ms
# 131: 480x480 2 pomadasys_argenteuss, 0.8ms
# 132: 480x480 2 gazza_minutas, 1 lujanus_gibbus, 1 lutjanus_fulviflamma, 2 lutjanus_fulvuss, 2 scomberoides_tols, 0.8ms
# 133: 480x480 1 lutjanus_johnii, 0.8ms
# 134: 480x480 1 lutjanus_fulvus, 3 lutjanus_johniis, 0.8ms
# 135: 480x480 (no detections), 0.8ms
# 136: 480x480 2 mulloidichtys_vanicolensiss, 0.8ms
# 137: 480x480 (no detections), 0.8ms
# 138: 480x480 (no detections), 0.8ms
# 139: 480x480 (no detections), 0.8ms
# 140: 480x480 1 chirocentrus_dorab, 0.8ms
# 141: 480x480 1 chirocentrus_dorab, 0.8ms
# 142: 480x480 1 lutjanus_johnii, 1 parupeneus_heptacanthus, 1 upeneus_vittatus, 0.8ms
# 143: 480x480 1 pomadasys_kaakan, 1 scomberomorus_commerson, 0.8ms
# 144: 480x480 1 pomadasys_argenteus, 0.8ms
# 145: 480x480 (no detections), 0.8ms
# 146: 480x480 (no detections), 0.8ms
# 147: 480x480 (no detections), 0.8ms
# 148: 480x480 (no detections), 0.8ms
# 149: 480x480 (no detections), 0.8ms
# 150: 480x480 1 gymnocranius_grandoculis, 0.8ms
# 151: 480x480 (no detections), 0.8ms
# 152: 480x480 1 lutjanus_johnii, 0.8ms
# 153: 480x480 (no detections), 0.8ms
# 154: 480x480 (no detections), 0.8ms
# 155: 480x480 (no detections), 0.8ms
# 156: 480x480 (no detections), 0.8ms
# 157: 480x480 (no detections), 0.8ms
# 158: 480x480 1 lujanus_gibbus, 0.8ms
# 159: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 160: 480x480 (no detections), 0.8ms
# 161: 480x480 1 lujanus_gibbus, 2 lutjanus_fulvuss, 0.8ms
# 162: 480x480 (no detections), 0.8ms
# 163: 480x480 2 lutjanus_fulvuss, 0.8ms
# 164: 480x480 1 lutjanus_fulvus, 3 scomberoides_tols, 2 upeneus_vittatuss, 0.8ms
# 165: 480x480 8 lutjanus_fulvuss, 0.8ms
# 166: 480x480 5 lutjanus_fulvuss, 2 lutjanus_johniis, 0.8ms
# 167: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 168: 480x480 1 lutjanus_fulvus, 0.8ms
# 169: 480x480 1 lutjanus_fulvus, 0.8ms
# 170: 480x480 1 aurigequula_fasciata, 0.8ms
# 171: 480x480 1 chirocentrus_dorab, 1 lutjanus_johnii, 0.8ms
# 172: 480x480 1 chirocentrus_dorab, 1 lutjanus_johnii, 0.8ms
# 173: 480x480 (no detections), 0.8ms
# 174: 480x480 1 caranx_ignobilis, 0.8ms
# 175: 480x480 1 caranx_ignobilis, 0.8ms
# 176: 480x480 1 pomadasys_argenteus, 0.8ms
# 177: 480x480 1 pomadasys_kaakan, 0.8ms
# 178: 480x480 1 pomadasys_kaakan, 0.8ms
# 179: 480x480 1 gymnocranius_grandoculis, 0.8ms
# 180: 480x480 1 aurigequula_fasciata, 2 pomadasys_argenteuss, 0.8ms
# 181: 480x480 (no detections), 0.8ms
# 182: 480x480 (no detections), 0.8ms
# 183: 480x480 (no detections), 0.8ms
# 184: 480x480 1 lujanus_gibbus, 0.8ms
# 185: 480x480 3 lutjanus_fulvuss, 0.8ms
# 186: 480x480 2 lutjanus_fulviflammas, 0.8ms
# 187: 480x480 2 lutjanus_fulviflammas, 0.8ms
# 188: 480x480 2 lutjanus_fulviflammas, 0.8ms
# 189: 480x480 2 lutjanus_fulviflammas, 0.8ms
# 190: 480x480 2 lutjanus_fulvuss, 1 lutjanus_johnii, 0.8ms
# 191: 480x480 1 lujanus_gibbus, 0.8ms
# 192: 480x480 1 lutjanus_fulvus, 0.8ms
# 193: 480x480 1 lujanus_gibbus, 1 lutjanus_fulvus, 0.8ms
# 194: 480x480 2 lujanus_gibbuss, 0.8ms
# 195: 480x480 (no detections), 0.8ms
# 196: 480x480 1 caranx_ignobilis, 0.8ms
# 197: 480x480 (no detections), 0.8ms
# 198: 480x480 2 lutjanus_fulviflammas, 1 lutjanus_fulvus, 1 lutjanus_johnii, 0.8ms
# 199: 480x480 (no detections), 0.8ms
# 200: 480x480 1 lutjanus_johnii, 0.8ms
# 201: 480x480 (no detections), 0.8ms
# 202: 480x480 (no detections), 0.8ms
# 203: 480x480 (no detections), 0.8ms
# 204: 480x480 (no detections), 0.8ms
# 205: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 206: 480x480 1 chirocentrus_dorab, 1 lutjanus_johnii, 0.8ms
# 207: 480x480 2 lutjanus_johniis, 0.8ms
# 208: 480x480 2 lutjanus_johniis, 0.8ms
# 209: 480x480 2 lutjanus_johniis, 0.8ms
# 210: 480x480 1 caranx_ignobilis, 3 lutjanus_johniis, 0.8ms
# 211: 480x480 1 caranx_ignobilis, 3 lutjanus_johniis, 0.8ms
# 212: 480x480 (no detections), 0.8ms
# 213: 480x480 (no detections), 0.8ms
# 214: 480x480 1 alectis_ciliaris, 0.8ms
# 215: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 216: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 217: 480x480 1 variola_albimarginata, 0.8ms
# 218: 480x480 (no detections), 0.8ms
# 219: 480x480 (no detections), 0.8ms
# 220: 480x480 (no detections), 0.8ms
# 221: 480x480 (no detections), 0.8ms
# 222: 480x480 (no detections), 0.8ms
# 223: 480x480 (no detections), 0.8ms
# 224: 480x480 (no detections), 0.8ms
# 225: 480x480 (no detections), 0.8ms
# 226: 480x480 (no detections), 0.8ms
# 227: 480x480 1 lutjanus_johnii, 0.8ms
# 228: 480x480 1 parupeneus_indicus, 0.8ms
# 229: 480x480 (no detections), 0.8ms
# 230: 480x480 (no detections), 0.8ms
# 231: 480x480 (no detections), 0.8ms
# 232: 480x480 2 decapterus_macarelluss, 4 upeneus_vittatuss, 0.8ms
# 233: 480x480 (no detections), 0.8ms
# 234: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 235: 480x480 (no detections), 0.8ms
# 236: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 237: 480x480 2 parupeneus_heptacanthuss, 0.8ms
# 238: 480x480 2 parupeneus_heptacanthuss, 0.8ms
# 239: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 240: 480x480 (no detections), 0.8ms
# 241: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 242: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 243: 480x480 1 pomadasys_kaakan, 0.8ms
# 244: 480x480 (no detections), 0.8ms
# 245: 480x480 2 chirocentrus_dorabs, 1 pomadasys_argenteus, 0.8ms
# 246: 480x480 1 lujanus_gibbus, 1 lutjanus_fulvus, 0.8ms
# 247: 480x480 1 lujanus_gibbus, 1 lutjanus_fulvus, 0.8ms
# 248: 480x480 1 pomadasys_kaakan, 0.8ms
# 249: 480x480 (no detections), 0.8ms
# 250: 480x480 1 lutjanus_bohar, 0.8ms
# 251: 480x480 2 lutjanus_johniis, 0.8ms
# 252: 480x480 1 alectis_ciliaris, 0.8ms
# 253: 480x480 (no detections), 0.8ms
# 254: 480x480 1 lutjanus_fulvus, 0.8ms
# 255: 480x480 1 lutjanus_fulvus, 0.8ms
# 256: 480x480 (no detections), 0.8ms
# 257: 480x480 1 gymnocranius_grandoculis, 0.8ms
# 258: 480x480 (no detections), 0.8ms
# 259: 480x480 (no detections), 0.8ms
# 260: 480x480 (no detections), 0.8ms
# 261: 480x480 1 gymnocranius_grandoculis, 1 lujanus_gibbus, 0.8ms
# 262: 480x480 (no detections), 0.8ms
# 263: 480x480 (no detections), 0.8ms
# 264: 480x480 (no detections), 0.8ms
# 265: 480x480 1 parupeneus_indicus, 0.8ms
# 266: 480x480 (no detections), 0.8ms
# 267: 480x480 1 rastrelliger_kanagurta, 0.8ms
# 268: 480x480 1 upeneus_vittatus, 0.8ms
# 269: 480x480 1 upeneus_vittatus, 0.8ms
# 270: 480x480 1 upeneus_vittatus, 0.8ms
# 271: 480x480 1 gymnocranius_grandoculis, 0.8ms
# 272: 480x480 1 lutjanus_johnii, 0.8ms
# 273: 480x480 (no detections), 0.8ms
# 274: 480x480 1 lutjanus_johnii, 0.8ms
# 275: 480x480 1 parupeneus_heptacanthus, 0.8ms
# 276: 480x480 (no detections), 0.8ms
# 277: 480x480 1 lutjanus_johnii, 0.8ms
# 278: 480x480 (no detections), 0.8ms
# 279: 480x480 1 lujanus_gibbus, 1 lutjanus_fulvus, 1 lutjanus_johnii, 1 parupeneus_indicus, 0.8ms
# 280: 480x480 1 lujanus_gibbus, 1 lutjanus_fulvus, 1 lutjanus_johnii, 1 parupeneus_indicus, 0.8ms
# 281: 480x480 (no detections), 0.8ms
# 282: 480x480 (no detections), 0.8ms
# 283: 480x480 (no detections), 0.8ms
# 284: 480x480 1 caranx_ignobilis, 0.8ms
# 285: 480x480 1 caranx_ignobilis, 0.8ms
# 286: 480x480 (no detections), 0.8ms
# 287: 480x480 (no detections), 0.8ms
# 288: 480x480 (no detections), 0.8ms
# 289: 480x480 1 alectis_ciliaris, 1 caranx_ignobilis, 1 lutjanus_johnii, 0.8ms
# 290: 480x480 1 alectis_ciliaris, 1 caranx_ignobilis, 1 lutjanus_johnii, 0.8ms
# 291: 480x480 1 alectis_ciliaris, 1 caranx_ignobilis, 1 lutjanus_johnii, 0.8ms
# 292: 480x480 1 scomberoides_tol, 0.8ms
# 293: 480x480 (no detections), 0.8ms
# 294: 480x480 2 lutjanus_johniis, 0.8ms
# Speed: 1.1ms preprocess, 0.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 480)
# Match summary:
#  match
# MISMATCH        335
# NO_DETECTION    108
# MATCH            18
# Name: count, dtype: int64
#
# Saved merged file with matches to: predictions_with_groundtruth_matches.csv
