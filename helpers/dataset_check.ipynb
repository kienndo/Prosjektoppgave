# %%
import os
import pandas as pd

# %%
DATA_DIR = "../data_csv/"
IMAGES_DIR = "../data_images/"

timor_leste_data_path = os.path.join(DATA_DIR, "timor-leste.csv") # Annotation info for ground truth

# Read annotation info (Timor-leste)
df_tl_ann = pd.read_csv(timor_leste_data_path, encoding="utf-8-sig", header=0, skiprows=1)
df_tl_ann = df_tl_ann[["image_file", "catch_name_en", "Species_name", "Family"]]

# %%
# Filter out relevant images
relevant_species = ['Alectis ciliaris', 'Aphareus rutilans', 'Caranx ignobilis', 'Caranx lugubris', 'Caranx melampygus', 'Caranx sexfasciatus', 'Chirocentrus dorab', 'Chirocentrus nudus', 'Decapterus macrosoma', 'Elagatis bipinnulata', 'Epinephelus maculatus', 'Epinephelus radiatus', 'Etelis carbunculus', 'Gymnocranius grandoculis', 'Katsuwonus pelamis', 'Lethrinus atkinsoni', 'Lethrinus erythracanthus', 'Lethrinus obsoletus', 'Lethrinus ornatus', 'Lutjanus bohar', 'Lutjanus fulviflamma', 'Lutjanus fulvus', 'Lutjanus gibbus', 'Lutjanus johnii', 'Lutjanus kasmira', 'Lutjanus rivulatus', 'Lutjanus russellii', 'Lutjanus timoriensis', 'Monotaxis grandoculis', 'Psettodes erumei', 'Rastrelliger kanagurta', 'Sardinella albella', 'Scolopsis lineata', 'Scolopsis vosmeri', 'Scomberoides lysan', 'Scomberomorus commerson', 'Seriola dumerili', 'Variola albimarginata']

# Read annotation info (Timor-leste)
df_tl_ann = pd.read_csv(timor_leste_data_path, encoding="utf-8-sig", header=0, skiprows=1)
df_tl_ann = df_tl_ann[["image_file", "catch_name_en", "Species_name", "Family"]]

# Filter by species in relevant_species
df_filtered = df_tl_ann[df_tl_ann["Species_name"].isin(relevant_species)]

# Keep only images that actually exist
existing_files = set(os.listdir(IMAGES_DIR))

df_filtered = df_filtered[df_filtered["image_file"].isin(existing_files)]

# Convert to list of filenames
filtered_images= df_filtered["image_file"].tolist()

print("Total annotated images:", len(df_tl_ann))
print("Relevant images", len(df_filtered))
print("Unique final JPGs:", len(set(filtered_images)))
# Out:
# Total annotated images: 603
# Relevant images 248
# Unique final JPGs: 217

# %%
raw = """

"""

classes = [line.strip() for line in raw.splitlines() if line.strip()]

# 2) Format: "Genus species" (first word capitalized, others lowercase)
def format_name(name: str) -> str:
    # Leave codes / single tokens as-is
    if "_" not in name:
        return name

    parts = name.split("_")
    parts[0] = parts[0].capitalize()          # Genus
    parts[1:] = [p.lower() for p in parts[1:]]  # species etc.
    return " ".join(parts)

input_species = [format_name(n) for n in classes]

# %%
registered_species = set(df_tl_ann["catch_name_en"].dropna().astype(str).str.strip().unique())

input_species = [
    "Blacksaddle filefish",
    "Blue streak cleaner wrasse",
    "Butterfly fish",
    "Checkerboard wrasse",
    "Clark's anemonefish",
    "Commerson's frogfish",
    "Lionfish",
    "Longfin bannerfish",
    "Manybar goatfish",
    "Moorish idol",
    "Pyramid butterflyfish",
    "Redtoothed triggerfish",
    "Reticulate dascyllus",
    "Ribboned sweetlips",
    "Sea goldie",
    "Sergeant major fish",
    "Teira batfish",
    "Weber's chromis"
]

input_species = set([s.strip() for s in input_species])

# Compare sets
intersection = registered_species.intersection(input_species)
only_in_input = input_species - registered_species
only_in_registered = registered_species - input_species

# Print results
print("Species found in BOTH input and dataset:")
print(sorted(intersection), "\n")

print("Species in INPUT but NOT in dataset:")
print(sorted(only_in_input), "\n")

print("Species in dataset but NOT in input list:")
print(f"(Showing first 20) {sorted(list(only_in_registered))[:20]}")
# Out:
# Species found in BOTH input and dataset:
# []
#
# Species in INPUT but NOT in dataset:
# ['Blacksaddle filefish', 'Blue streak cleaner wrasse', 'Butterfly fish', 'Checkerboard wrasse', "Clark's anemonefish", "Commerson's frogfish", 'Lionfish', 'Longfin bannerfish', 'Manybar goatfish', 'Moorish idol', 'Pyramid butterflyfish', 'Redtoothed triggerfish', 'Reticulate dascyllus', 'Ribboned sweetlips', 'Sea goldie', 'Sergeant major fish', 'Teira batfish', "Weber's chromis"]
#
# Species in dataset but NOT in input list:
# (Showing first 20) ['Barracuda & Jacks/Trevally/Other Scad', 'Barracuda & Jacks/Trevally/Other Scad & Jacks/Trevally/Other Scad', 'Barracuda & Jacks/Trevally/Other Scad & Snapper/seaperch', 'Bream & Emperor & Snapper/seaperch & Unknown & Unknown', 'Bream & Grouper & Unknown', 'Bream & Jacks/Trevally/Other Scad', 'Bream & Jacks/Trevally/Other Scad & Stingrays', 'Bream & Snapper/seaperch', 'Emperor', 'Emperor & Goatfish & Spinefoot & Tuna/Bonito/Other Mackerel', 'Emperor & Jacks/Trevally/Other Scad & Jacks/Trevally/Other Scad & Spinefoot', 'Emperor & Jacks/Trevally/Other Scad & Spinefoot', 'Emperor & Moontail bullseye & Snapper/seaperch & Spinefoot', 'Emperor & Snapper/seaperch', 'Emperor & Snapper/seaperch & Spinefoot', 'Emperor & Snapper/seaperch & Spinefoot & Surgeonfish', 'Emperor & Snapper/seaperch & Unicornfish', 'Emperor & Spinefoot', 'Flying fish & Fusilier & Mackerel scad & Parrotfish & Soldierfish', 'Flying fish & Garfish & Jacks/Trevally/Other Scad']

# %%
import os
import shutil

# Path to your species folders
ROOT_DIR = "iNaturalist"

# Path for the filtered output
OUT_DIR = "iNaturalist_filtered"
os.makedirs(OUT_DIR, exist_ok=True)

# === 1) Read species directly from df_tl_ann ===
raw_species = df_tl_ann["Species_name"].unique()
print(f"Total unique species in df_tl_ann: {len(raw_species)}")

# === 2) Normalize species: replace spaces with underscores ===
relevant_species = {sp.replace(" ", "_").strip() for sp in raw_species}

# === 3) Get folder names ONLY (no files) ===
folder_names = [
    folder for folder in os.listdir(ROOT_DIR)
    if os.path.isdir(os.path.join(ROOT_DIR, folder))
]

# === 4) Find matches ===
matches = sorted([f for f in folder_names if f in relevant_species])
non_matches = sorted([f for f in folder_names if f not in relevant_species])

print(f"\nTotal matching folders: {len(matches)}")

# === 5) Copy only matching folders into OUT_DIR ===
for m in matches:
    src_path = os.path.join(ROOT_DIR, m)
    dst_path = os.path.join(OUT_DIR, m)

    # Copy entire directory tree
    if os.path.exists(dst_path):
        shutil.rmtree(dst_path)  # remove old version if exists

    shutil.copytree(src_path, dst_path)
    print(f"Copied: {m}")

print(f"\nFiltered dataset created at: {OUT_DIR}")

# === 6) Optional: print non-matching folders ===
print("\n=== Non-matching folder names ===")
for nm in non_matches:
    print("  ✖", nm)
# Out:
# Total unique species in df_tl_ann: 97
#
# Total matching folders: 28
# Copied: Acanthocybium_solandri
# Copied: Alectis_ciliaris
# Copied: Aurigequula_fasciata
# Copied: Caranx_ignobilis
# Copied: Chirocentrus_dorab
# Copied: Decapterus_macarellus
# Copied: Gazza_minuta
# Copied: Gymnocranius_grandoculis
# Copied: Lethrinus_mahsena
# Copied: Lutjanus_fulviflamma
# Copied: Lutjanus_fulvus
# Copied: Lutjanus_gibbus
# Copied: Lutjanus_johnii
# Copied: Lutjanus_russellii
# Copied: Monotaxis_grandoculis
# Copied: Mulloidichthys_vanicolensis
# Copied: Neoniphon_sammara
# Copied: Parupeneus_heptacanthus
# Copied: Parupeneus_indicus
# Copied: Pomadasys_argenteus
# Copied: Pomadasys_kaakan
# Copied: Pristigenys_niphonia
# Copied: Pseudobalistes_flavimarginatus
# Copied: Rastrelliger_kanagurta
# Copied: Sardinella_albella
# Copied: Scomberoides_tol
# Copied: Scomberomorus_commerson
# Copied: Upeneus_vittatus
#
# Filtered dataset created at: iNaturalist_filtered
#
# === Non-matching folder names ===
#   ✖ Ablennes_hians
#   ✖ Acanthopagrus_bifasciatus
#   ✖ Acanthurus_mata
#   ✖ Acanthurus_nigrofuscus
#   ✖ Acanthurus_thompsoni
#   ✖ Acanthurus_triostegus
#   ✖ Aethaloperca_rogaa
#   ✖ Albula_vulpes
#   ✖ Alepes_djedaba
#   ✖ Aluterus_monoceros
#   ✖ Aluterus_scriptus
#   ✖ Amanses_scopas
#   ✖ Amblygaster_leiogaster
#   ✖ Antigonia_rubescens
#   ✖ Anyperodon_leucogrammicus
#   ✖ Aphareus_furca
#   ✖ Apistus_carinatus
#   ✖ Apolemichthys_trimaculatus
#   ✖ Argyrops_filamentosus
#   ✖ Ariomma_indicum
#   ✖ Arnoglossus_dalgleishi
#   ✖ Atherinomorus_duodecimalis
#   ✖ Atherinomorus_lacunosus
#   ✖ Atule_mate
#   ✖ Aulostomus_chinensis
#   ✖ Auxis_rochei
#   ✖ Balistapus_undulatus
#   ✖ Balistoides_conspicillum
#   ✖ Balistoides_viridescens
#   ✖ Bodianus_anthioides
#   ✖ Bodianus_axillaris
#   ✖ Bodianus_diana
#   ✖ Bodianus_leucosticticus
#   ✖ Bodianus_opercularis
#   ✖ Bodianus_trilineatus
#   ✖ Bolbometopon_muricatum
#   ✖ Bothus_pantherinus
#   ✖ Calotomus_carolinus
#   ✖ Cantherhines_dumerilii
#   ✖ Canthidermis_maculata
#   ✖ Carangoides_armatus
#   ✖ Carangoides_equula
#   ✖ Carangoides_ferdau
#   ✖ Carangoides_gymnostethus
#   ✖ Carangoides_malabaricus
#   ✖ Caranx_heberi
#   ✖ Centropyge_bicolor
#   ✖ Cephalopholis_aurantia
#   ✖ Cephalopholis_boenak
#   ✖ Cephalopholis_leopardus
#   ✖ Cephalopholis_miniata
#   ✖ Cephalopholis_nigripinnis
#   ✖ Cephalopholis_sonnerati
#   ✖ Cephalopholis_spiloparaea
#   ✖ Cetoscarus_bicolor
#   ✖ Chanos_chanos
#   ✖ Cheilinus_chlorourus
#   ✖ Cheilio_inermis
#   ✖ Cheilopogon_atrisignis
#   ✖ Cheilopogon_cyanopterus
#   ✖ Cheilopogon_furcatus
#   ✖ Cheimerius_nufar
#   ✖ Chlorurus_atrilunula
#   ✖ Chlorurus_sordidus
#   ✖ Cirrhitichthys_oxycephalus
#   ✖ Cociella_crocodilus
#   ✖ Coris_caudimacula
#   ✖ Coris_cuvieri
#   ✖ Coris_formosa
#   ✖ Crenidens_crenidens
#   ✖ Crossorhombus_valderostratus
#   ✖ Ctenochaetus_strigosus
#   ✖ Cubiceps_whiteleggii
#   ✖ Cyclichthys_orbicularis
#   ✖ Cypselurus_naresii
#   ✖ Cypselurus_oligolepis
#   ✖ Cyttopsis_rosea
#   ✖ Dactyloptena_orientalis
#   ✖ Decapterus_russelli
#   ✖ Dendrochirus_brachypterus
#   ✖ Dendrochirus_zebra
#   ✖ Dermatolepis_striolata
#   ✖ Dipterygonotus_balteatus
#   ✖ Drepane_longimana
#   ✖ Echidna_polyzona
#   ✖ Elops_machnata
#   ✖ Encrasicholina_devisi
#   ✖ Encrasicholina_heteroloba
#   ✖ Engyprosopon_grandisquama
#   ✖ Epibulus_insidiator
#   ✖ Epinephelus_chabaudi
#   ✖ Epinephelus_chlorostigma
#   ✖ Epinephelus_coeruleopunctatus
#   ✖ Epinephelus_epistictus
#   ✖ Epinephelus_fasciatus
#   ✖ Epinephelus_flavocaeruleus
#   ✖ Epinephelus_fuscoguttatus
#   ✖ Epinephelus_lanceolatus
#   ✖ Epinephelus_longispinis
#   ✖ Epinephelus_macrospilos
#   ✖ Epinephelus_malabaricus
#   ✖ Epinephelus_morrhua
#   ✖ Epinephelus_multinotatus
#   ✖ Epinephelus_poecilonotus
#   ✖ Epinephelus_polyphekadion
#   ✖ Epinephelus_rivulatus
#   ✖ Epinephelus_tauvina
#   ✖ Equulites_elongatus
#   ✖ Equulites_leuciscus
#   ✖ Etrumeus_teres
#   ✖ Euleptorhamphus_viridis
#   ✖ Gerres_longirostris
#   ✖ Gerres_oyena
#   ✖ Gnathanodon_speciosus
#   ✖ Gnathodentex_aureolineatus
#   ✖ Gracila_albomarginata
#   ✖ Grammistes_sexlineatus
#   ✖ Gymnocaesio_gymnoptera
#   ✖ Gymnomuraena_zebra
#   ✖ Gymnosarda_unicolor
#   ✖ Gymnothorax_flavimarginatus
#   ✖ Gymnothorax_griseus
#   ✖ Gymnothorax_javanicus
#   ✖ Gymnothorax_monochrous
#   ✖ Gymnothorax_nudivomer
#   ✖ Gymnothorax_pictus
#   ✖ Gymnothorax_rueppellii
#   ✖ Halichoeres_hortulanus
#   ✖ Halichoeres_scapularis
#   ✖ Hemigymnus_fasciatus
#   ✖ Herklotsichthys_spilurus
#   ✖ Heteropriacanthus_cruentatus
#   ✖ Hilsa_kelee
#   ✖ Hipposcarus_harid
#   ✖ Hologymnosus_annulatus
#   ✖ Hypoatherina_temminckii
#   ✖ Hyporhamphus_dussumieri
#   ✖ Iniistius_pentadactylus
#   ✖ Istiophorus_platypterus
#   ✖ Johnius_amblycephalus
#   ✖ Kuhlia_rupestris
#   ✖ Kyphosus_cinerascens
#   ✖ Labroides_dimidiatus
#   ✖ Lamnostoma_orientalis
#   ✖ Leiognathus_berbis
#   ✖ Leiognathus_equulus
#   ✖ Lepidocybium_flavobrunneum
#   ✖ Leptoscarus_vaigiensis
#   ✖ Lethrinus_harak
#   ✖ Lethrinus_lentjan
#   ✖ Liza_macrolepis
#   ✖ Liza_melinoptera
#   ✖ Liza_vaigiensis
#   ✖ Lobotes_surinamensis
#   ✖ Lophiodes_mutilus
#   ✖ Lophiomus_setigerus
#   ✖ Lophodiodon_calori
#   ✖ Lutjanus_argentimaculatus
#   ✖ Lutjanus_bengalensis
#   ✖ Lutjanus_monostigma
#   ✖ Lutjanus_sanguineus
#   ✖ Macolor_niger
#   ✖ Makaira_indica
#   ✖ Malacocephalus_laevis
#   ✖ Megalaspis_cordyla
#   ✖ Melichthys_niger
#   ✖ Melichthys_vidua
#   ✖ Mene_maculata
#   ✖ Mola_mola
#   ✖ Monodactylus_argenteus
#   ✖ Moolgarda_seheli
#   ✖ Muraenesox_bagio
#   ✖ Muraenesox_cinereus
#   ✖ Myripristis_murdjan
#   ✖ Naso_annulatus
#   ✖ Naso_brachycentron
#   ✖ Naso_brevirostris
#   ✖ Naso_elegans
#   ✖ Naso_hexacanthus
#   ✖ Naso_thynnoides
#   ✖ Naso_unicornis
#   ✖ Naso_vlamingii
#   ✖ Nemipterus_japonicus
#   ✖ Neoniphon_opercularis
#   ✖ Novaculichthys_taeniourus
#   ✖ Odonus_niger
#   ✖ Ostichthys_archiepiscopus
#   ✖ Otolithes_ruber
#   ✖ Oxycheilinus_digramma
#   ✖ Oxymonacanthus_longirostris
#   ✖ Paracanthurus_hepatus
#   ✖ Paracirrhites_forsteri
#   ✖ Parapercis_hexophtalma
#   ✖ Paraplagusia_bilineata
#   ✖ Parascolopsis_eriomma
#   ✖ Parastromateus_niger
#   ✖ Pardachirus_marmoratus
#   ✖ Pardachirus_morrowi
#   ✖ Parexocoetus_brachypterus
#   ✖ Parexocoetus_mento
#   ✖ Parupeneus_macronemus
#   ✖ Parupeneus_pleurostigma
#   ✖ Parupeneus_rubescens
#   ✖ Parupeneus_trifasciatus
#   ✖ Pinjalo_pinjalo
#   ✖ Pisodonophis_boro
#   ✖ Platax_orbicularis
#   ✖ Platax_teira
#   ✖ Platybelone_platyura
#   ✖ Platycephalus_indicus
#   ✖ Plectorhinchus_chubbi
#   ✖ Plectorhinchus_flavomaculatus
#   ✖ Plectorhinchus_gaterinus
#   ✖ Plectorhinchus_gibbosus
#   ✖ Plectorhinchus_picus
#   ✖ Plectorhinchus_schotaf
#   ✖ Plectorhinchus_sordidus
#   ✖ Plectropomus_laevis
#   ✖ Plectropomus_pessuliferus
#   ✖ Plectropomus_punctatus
#   ✖ Plicofollis_polystaphylodon
#   ✖ Plotosus_lineatus
#   ✖ Polysteganus_coeruleopunctatus
#   ✖ Pomacanthus_chrysurus
#   ✖ Pomacanthus_imperator
#   ✖ Pomacanthus_maculosus
#   ✖ Pomacanthus_semicirculatus
#   ✖ Pomadasys_commersonnii
#   ✖ Pomadasys_olivaceus
#   ✖ Pomadasys_stridens
#   ✖ Pomatomus_saltatrix
#   ✖ Pristipomoides_zonatus
#   ✖ Prognichthys_brevipinnis
#   ✖ Promethichthys_prometheus
#   ✖ Pseudalutarius_nasicornis
#   ✖ Pseudechidna_brummeri
#   ✖ Pseudocaranx_dentex
#   ✖ Pseudorhombus_arsius
#   ✖ Pteragogus_flagellifer
#   ✖ Pterocaesio_chrysozona
#   ✖ Pterocaesio_pisang
#   ✖ Pterocaesio_tile
#   ✖ Pterois_antennata
#   ✖ Pterois_miles
#   ✖ Pterois_mombasae
#   ✖ Pterois_volitans
#   ✖ Pygoplites_diacanthus
#   ✖ Rhinecanthus_aculeatus
#   ✖ Rhinecanthus_rectangulus
#   ✖ Rogadius_pristiger
#   ✖ Sarda_orientalis
#   ✖ Sardinella_melanura
#   ✖ Sargocentron_caudimaculatum
#   ✖ Sargocentron_diadema
#   ✖ Sargocentron_ittodai
#   ✖ Sargocentron_praslin
#   ✖ Sargocentron_punctatissimum
#   ✖ Sargocentron_spiniferum
#   ✖ Sargocentron_violaceum
#   ✖ Saurida_gracilis
#   ✖ Saurida_tumbil
#   ✖ Scarus_caudofasciatus
#   ✖ Scarus_falcipinnis
#   ✖ Scarus_viridifucatus
#   ✖ Scatophagus_tetracanthus
#   ✖ Scolopsis_frenata
#   ✖ Scolopsis_ghanam
#   ✖ Scorpaenopsis_diabolus
#   ✖ Scorpaenopsis_gibbosa
#   ✖ Secutor_insidiator
#   ✖ Secutor_ruconius
#   ✖ Selar_crumenophthalmus
#   ✖ Siganus_argenteus
#   ✖ Siganus_canaliculatus
#   ✖ Siganus_stellatus
#   ✖ Sillago_sihama
#   ✖ Sorsogona_prionota
#   ✖ Sphyraena_barracuda
#   ✖ Spratelloides_delicatulus
#   ✖ Stethojulis_albovittata
#   ✖ Stethojulis_strigiventer
#   ✖ Stolephorus_indicus
#   ✖ Strophidon_sathete
#   ✖ Sufflamen_bursa
#   ✖ Sufflamen_chrysopterum
#   ✖ Sufflamen_fraenatum
#   ✖ Synagrops_japonicus
#   ✖ Synodus_indicus
#   ✖ Terapon_jarbua
#   ✖ Tetrapturus_audax
#   ✖ Thalassoma_amblycephalum
#   ✖ Thalassoma_hebraicum
#   ✖ Thalassoma_lunare
#   ✖ Thalassoma_quinquevittatum
#   ✖ Thalassoma_trilobatum
#   ✖ Thryssa_baelama
#   ✖ Thryssa_setirostris
#   ✖ Thunnus_alalunga
#   ✖ Thunnus_albacares
#   ✖ Thunnus_tonggol
#   ✖ Trachinocephalus_myops
#   ✖ Trachinotus_baillonii
#   ✖ Trachinotus_blochii
#   ✖ Trachinotus_botla
#   ✖ Tylosurus_crocodilus_crocodilus
#   ✖ Ulua_mentalis
#   ✖ Upeneus_moluccensis
#   ✖ Uraspis_secunda
#   ✖ Uroconger_lepturus
#   ✖ Uropterygius_marmoratus
#   ✖ Valamugil_buchanani
#   ✖ Valamugil_cunnesius
#   ✖ Valamugil_engeli
#   ✖ Ventrifossa_petersonii
#   ✖ Xanthichthys_lineopunctatus
#   ✖ Zebrasoma_velifer
