# %%
# !pip install fitz frontend
# Out:
# Requirement already satisfied: fitz in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (0.0.1.dev2)
# Collecting frontend
#   Downloading frontend-0.0.3-py3-none-any.whl.metadata (847 bytes)
# Requirement already satisfied: configobj in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (5.0.9)
# Requirement already satisfied: configparser in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (7.2.0)
# Requirement already satisfied: httplib2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (0.31.0)
# Requirement already satisfied: nibabel in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (5.3.3)
# Requirement already satisfied: nipype in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (1.10.0)
# Requirement already satisfied: numpy in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (2.2.6)
# Requirement already satisfied: pandas in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (2.3.3)
# Requirement already satisfied: pyxnat in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (1.6.4)
# Requirement already satisfied: scipy in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from fitz) (1.16.3)
# Collecting starlette>=0.12.0 (from frontend)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting uvicorn>=0.7.1 (from frontend)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting itsdangerous>=1.1.0 (from frontend)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting aiofiles (from frontend)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from starlette>=0.12.0->frontend) (4.12.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from starlette>=0.12.0->frontend) (4.15.0)
# Requirement already satisfied: click>=7.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from uvicorn>=0.7.1->frontend) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from uvicorn>=0.7.1->frontend) (0.16.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from httplib2->fitz) (3.2.5)
# Requirement already satisfied: packaging>=20 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nibabel->fitz) (25.0)
# Requirement already satisfied: networkx>=2.5 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (3.5)
# Requirement already satisfied: prov>=1.5.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (2.1.1)
# Requirement already satisfied: pydot>=1.2.3 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (2.9.0.post0)
# Requirement already satisfied: rdflib>=5.0.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (7.5.0)
# Requirement already satisfied: simplejson>=3.8.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (3.20.2)
# Requirement already satisfied: traits>=6.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (7.0.2)
# Requirement already satisfied: filelock>=3.0.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (3.19.1)
# Requirement already satisfied: acres in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (0.5.0)
# Requirement already satisfied: etelemetry>=0.3.1 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (0.3.1)
# Requirement already satisfied: looseversion!=1.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (1.3.0)
# Requirement already satisfied: puremagic in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from nipype->fitz) (1.30)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from pandas->fitz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from pandas->fitz) (2025.2)
# Requirement already satisfied: lxml>=4.3 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from pyxnat->fitz) (6.0.2)
# Requirement already satisfied: requests>=2.20 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from pyxnat->fitz) (2.32.5)
# Requirement already satisfied: pathlib>=1.0 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.12.0->frontend) (3.11)
# Requirement already satisfied: colorama in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from click>=7.0->uvicorn>=0.7.1->frontend) (0.4.6)
# Requirement already satisfied: ci-info>=0.2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from etelemetry>=0.3.1->nipype->fitz) (0.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from python-dateutil>=2.2->nipype->fitz) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from requests>=2.20->pyxnat->fitz) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from requests>=2.20->pyxnat->fitz) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kienn\downloads\prosjektoppgave\gpu_env\lib\site-packages (from requests>=2.20->pyxnat->fitz) (2025.11.12)
# Downloading frontend-0.0.3-py3-none-any.whl (32 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: itsdangerous, aiofiles, uvicorn, starlette, frontend
# Successfully installed aiofiles-25.1.0 frontend-0.0.3 itsdangerous-2.2.0 starlette-0.50.0 uvicorn-0.38.0
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!/usr/bin/env python3
"""
extract_fish_allpages_no_tesseract.py

Extracts all fish illustrations from every page of
"Coastal Fishes of the Western Indian Ocean" Vol.2
using italic font detection from PDF metadata (PyMuPDF)
and fallback image-based slant analysis.

Output: folder tree and ZIP file with correctly named, cropped images.
"""

import os, re, zipfile, cv2, numpy as np, fitz
from pdf2image import convert_from_path
from PIL import Image

PDF_PATH = "2._wiof_volume_2_colour_plates.pdf"
OUT_DIR = "wiof_output_allpages"
ZIP_PATH = "wiof_output_allpages.zip"
DPI = 400
DEBUG_SAVE = False

os.makedirs(OUT_DIR, exist_ok=True)

# ============================================================
# === Italic detection helpers ===============================
# ============================================================

def fontname_looks_italic(fontname: str) -> bool:
    if not fontname:
        return False
    fn = fontname.lower()
    fn = re.sub(r"^[A-Z]{6}\+", "", fn)
    return any(k in fn for k in ["italic", "oblique", "slanted", "it", "ita"])

def detect_text_slant_angle(img_gray, bbox, expand=2):
    x0, y0, w, h = bbox
    ex = int(min(w, h) * 0.2) * expand
    x0e = max(0, int(x0 - ex))
    y0e = max(0, int(y0 - ex))
    x1e = min(img_gray.shape[1], int(x0 + w + ex))
    y1e = min(img_gray.shape[0], int(y0 + h + ex))
    crop = img_gray[y0e:y1e, x0e:x1e]
    if crop.size == 0:
        return None
    blur = cv2.GaussianBlur(crop, (3,3), 0)
    _, bw = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    if np.mean(bw) > 127:
        bw = 255 - bw
    edges = cv2.Canny(bw, 50, 150)
    ys, xs = np.nonzero(edges)
    if len(xs) < 30:
        return None
    coords = np.vstack([xs, ys]).astype(np.float64)
    coords -= coords.mean(axis=1, keepdims=True)
    U, S, Vt = np.linalg.svd(coords @ coords.T)
    principal = U[:, 0]
    dx, dy = principal[0], principal[1]
    angle_rad = np.arctan2(dy, dx)
    angle_deg = np.degrees(angle_rad)
    if angle_deg > 90:
        angle_deg -= 180
    if angle_deg <= -90:
        angle_deg += 180
    return angle_deg

def is_italic_span(span: dict, page_img_gray=None, scale=1.0, angle_thresh=3.0):
    fontname = span.get("font", "")
    if fontname_looks_italic(fontname):
        return True
    if page_img_gray is not None and "bbox" in span:
        x0, y0, x1, y1 = span["bbox"]
        x0 *= scale; y0 *= scale; x1 *= scale; y1 *= scale
        bbox_px = (x0, y0, x1 - x0, y1 - y0)
        angle = detect_text_slant_angle(page_img_gray, bbox_px)
        if angle is not None and abs(angle) >= angle_thresh:
            return True
    return False

# ============================================================
# === Process each page ======================================
# ============================================================

print(f"Processing all pages in {PDF_PATH} ...")
doc = fitz.open(PDF_PATH)
page_count = len(doc)
scale = DPI / 72.0

# render all pages once (saves time)
rendered_pages = convert_from_path(PDF_PATH, dpi=DPI)

all_matches = []

for page_index, (page_image, page_fitz) in enumerate(zip(rendered_pages, doc), start=1):
    print(f"\n=== Page {page_index}/{page_count} ===")
    page_dir = os.path.join(OUT_DIR, f"page_{page_index:03d}")
    os.makedirs(page_dir, exist_ok=True)

    # Save rendered image
    page_path = os.path.join(page_dir, f"page_{page_index:03d}.jpg")
    page_image.convert("RGB").save(page_path, "JPEG", quality=95)

    img_cv = cv2.imread(page_path)
    page_img_gray = cv2.cvtColor(img_cv, cv2.COLOR_BGR2GRAY)

    # --- Extract italic spans ---
    blocks = page_fitz.get_text("dict")["blocks"]
    italic_boxes, species_names = [], []

    for block in blocks:
        for line in block.get("lines", []):
            for span in line.get("spans", []):
                text = span.get("text", "").strip()
                if not text:
                    continue
                if re.match(r"^[A-Z][a-z]+ [a-z]+$", text):
                    if is_italic_span(span, page_img_gray=page_img_gray, scale=scale):
                        x0, y0, x1, y1 = span["bbox"]
                        x0 *= scale; y0 *= scale; x1 *= scale; y1 *= scale
                        italic_boxes.append((x0, y0, x1 - x0, y1 - y0))
                        species_names.append(text.replace(" ", "_"))

    print(f" → Detected {len(species_names)} italic species names.")

    # --- Detect fish contours ---
    blur = cv2.medianBlur(page_img_gray, 5)
    th = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                               cv2.THRESH_BINARY_INV, 51, 10)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (25,15))
    closed = cv2.morphologyEx(th, cv2.MORPH_CLOSE, kernel, iterations=2)
    contours, _ = cv2.findContours(closed, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    h, w = page_img_gray.shape
    page_area = w * h
    fish_boxes = []
    for c in contours:
        x, y, ww, hh = cv2.boundingRect(c)
        if ww * hh > page_area * 0.002:
            fish_boxes.append((x, y, ww, hh))
    print(f" → Found {len(fish_boxes)} fish-like regions.")

    # --- Match captions to fish boxes ---
    print("Matching fish boxes to nearest captions below them...")
    matches = []
    used_species, used_boxes = set(), set()
    for fi, (fx, fy, fw, fh) in enumerate(fish_boxes):
        fish_bottom = fy + fh
        fish_center_x = fx + fw / 2
        below_candidates = []
        for si, (tx, ty, tw, tht) in enumerate(italic_boxes):
            if si in used_species:
                continue
            if ty > fish_bottom and (ty - fish_bottom) < 500:
                horizontal_distance = abs(tx - fx)
                vertical_distance = abs(ty - fish_bottom)
                distance_score = vertical_distance + 0.5 * horizontal_distance
                below_candidates.append((distance_score, si, tx, ty, tw, tht))
        if below_candidates:
            below_candidates.sort(key=lambda x: x[0])
            _, si, tx, ty, tw, tht = below_candidates[0]
            species = species_names[si]
            matches.append((species, (fx, fy, fw, fh)))
            used_species.add(si)
            used_boxes.add(fi)

    remaining_species = [s for i, s in enumerate(species_names) if i not in used_species]
    remaining_fish = [b for i, b in enumerate(fish_boxes) if i not in used_boxes]
    for s, b in zip(remaining_species, remaining_fish):
        matches.append((s, b))

    print(f" → Matched {len(matches)} species to fish images.")

    # --- Crop and save ---
    pad = 25
    for species, (x, y, ww, hh) in matches:
        x0 = max(0, x - pad)
        y0 = max(0, y - pad)
        x1 = min(w, x + ww + pad)
        y1 = min(h, y + hh + pad)
        crop = img_cv[int(y0):int(y1), int(x0):int(x1)]
        species_dir = os.path.join(page_dir, species)
        os.makedirs(species_dir, exist_ok=True)
        out_path = os.path.join(species_dir, f"{species}_p{page_index:03d}.jpg")
        cv2.imwrite(out_path, crop, [int(cv2.IMWRITE_JPEG_QUALITY), 94])
        all_matches.append(out_path)

# ============================================================
# === Zip everything =========================================
# ============================================================

print("\nZipping all results...")
with zipfile.ZipFile(ZIP_PATH, "w", zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(OUT_DIR):
        for f in files:
            if f.lower().endswith(".jpg"):
                absf = os.path.join(root, f)
                relf = os.path.relpath(absf, OUT_DIR)
                zipf.write(absf, relf)

print("\n✅ Done. ZIP created:", ZIP_PATH)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 13
#       1 #!/usr/bin/env python3
#       2 """
#       3 extract_fish_allpages_no_tesseract.py
#       4
#    (...)     10 Output: folder tree and ZIP file with correctly named, cropped images.
#      11 """
# ---> 13 import os, re, zipfile, cv2, numpy as np, fitz
#      14 from pdf2image import convert_from_path
#      15 from PIL import Image
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\fitz\__init__.py:1
# ----> 1 from frontend import *
#       2 import tools
#       3 import os.path as op
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\__init__.py:1
# ----> 1 from .events import *
#       2 from . import config
#       3 from .components import *
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\events\__init__.py:1
# ----> 1 from .clipboard import *
#       2 from .event_mixins import *
#       3 from .hash_change import *
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\events\clipboard.py:2
#       1 from .event_mixins import ClipboardDataMixin
# ----> 2 from ..dom import Event
#       4 __all__ = ['ClipboardEvent']
#       7 class ClipboardEvent(Event, ClipboardDataMixin):
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\dom.py:439
#     435         except KeyError:
#     436             pass
# --> 439 from . import dispatcher
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\dispatcher.py:15
#      12 from starlette.endpoints import WebSocketEndpoint
#      13 from starlette.websockets import WebSocket
# ---> 15 from . import config, server
#      16 from .async_utils import later_await
#      18 __all__ = ['react']
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\frontend\server.py:24
#      21 __all__ = ['route', 'run']
#      23 app: Any = Starlette(debug=config.DEBUG)
# ---> 24 app.mount(config.STATIC_ROUTE, StaticFiles(directory=config.STATIC_DIRECTORY), name=config.STATIC_NAME)
#      25 app.add_middleware(GZipMiddleware)
#      26 app.add_middleware(
#      27     CORSMiddleware,
#      28     allow_origins=["*"],
#    (...)     31     allow_headers=["*"],
#      32 )
#
# File c:\Users\kienn\Downloads\Prosjektoppgave\gpu_env\Lib\site-packages\starlette\staticfiles.py:56, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      54 self.follow_symlink = follow_symlink
#      55 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory 'static/' does not exist
